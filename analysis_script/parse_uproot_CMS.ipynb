# %% [markdown]
# # HEP Jet assignment project - Data analysis and particle finding script

# %% [markdown]
# ## Import essential packages.
# ---
# * We will use [uproot](https://github.com/scikit-hep/uproot) packages to parse our .root file.
# * The content of function `particle properties` and `jet properties` is defined in `particle_properties.py` and `jet_properties.py`.

# %%
import uproot
import pandas as pd 
import numpy as np 
from particle_properties_uproot import particle_properties  #import particle properties helper function from particle_properties.py
from jet_properties_uproot import jet_properties  #import jet properties helper function from jet_properties.py
import h5py

# %% [markdown]
# ## Loading data, determine parameters, and assign variable
# ---

# %%
data  = uproot.open('./data/10K_event/tag_1_delphes_events.root')['Delphes']
#data.show()

particle = particle_properties(data)
jet = jet_properties(data)

Length = len(particle.event)
test_length = 10

PID_W_plus = 24 
PID_W_minus = -24
PID_DOWN = 1
PID_DOWN_VAR = -1
PID_UP = 2
PID_UP_BAR = -2
PID_STRANGE = 3
PID_STRANGE_BAR = -3
PID_CHARM = 4
PID_CHARM_BAR = -4
PID_BOTTOM = 5
PID_BOTTOM_BAR = -5
PID_TOP = 6
PID_TOP_BAR = -6

top_idx = np.zeros(len(particle.event))
top_daughter_idx_1 = np.zeros(len(particle.event))
top_daughter_pid_1 = np.zeros(len(particle.event))
top_daughter_idx_2 = np.zeros(len(particle.event))
top_daughter_pid_2 = np.zeros(len(particle.event))

top_bar_idx = np.zeros(len(particle.event))
top_bar_daughter_idx_1 = np.zeros(len(particle.event))
top_bar_daughter_pid_1 = np.zeros(len(particle.event))
top_bar_daughter_idx_2 = np.zeros(len(particle.event))
top_bar_daughter_pid_2 = np.zeros(len(particle.event))

parton_array = np.zeros([ len(particle.event) , 6, 7])

# %% [markdown]
# ## Event selection
# ---
# 1. Must contain:
#     * At least 2 b tagged jet.
#     * At least 6 jet exists.
#     * For each jet, require |$\eta$| < 2.5 and $P_{T}$ > 25GeV.

# %%
#Generate maker for each stage(event selection and jet selection.)
marker_event = []
marker_jet = []
marker_bjet = []

for i in range(len(particle.event)):
    marker_event.append(0)
    marker_jet.append(np.zeros([len(jet.pt[i])]))
    marker_bjet.append(np.zeros([len(jet.pt[i])]))


marker_event = np.asanyarray(marker_event)
marker_jet = np.asanyarray(marker_jet)
marker_bjet = np.asanyarray(marker_bjet)

#print(type(marker_event), type(marker_jet))
#print(marker_event.shape, marker_jet.shape)
# Out:
# /usr/local/lib64/python3.6/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
#Mark which event pass the selection
# print("+-----------------------------------------------------------------------------------------------------+")
# print("Start event selection.")
# for i in range(len(particle.event)):
#     num_of_eta_in_range = np.sum(jet.eta[i] < 2.4 ) 
#     num_of_jet = len(jet.pt[i])
#     num_of_btagged = np.sum(jet.btag[i] == 1)
#     if num_of_eta_in_range >= 6 and num_of_jet >=6 and num_of_btagged >= 2: 
#         marker_event[i] = 1
#     else :
#         pass
# print("Event selection doen.")
# print("+-----------------------------------------------------------------------------------------------------+")

#Mark which jet in each event pass the selection.
print("+-----------------------------------------------------------------------------------------------------+")
print("Start jet selection.")
for i in range(len(particle.event)):
    for j in range(len(jet.pt[i])):
        if jet.btag[i][j] == 1 and jet.pt[i][j] > 25 and np.abs(jet.eta[i][j]) < 2.5:
            marker_bjet[i][j] = 1 
        elif jet.pt[i][j] > 25 and np.abs(jet.eta[i][j]) < 2.5:
            marker_jet[i][j] = 1

for i in range(len(particle.event)):
    if np.sum(marker_jet[i] == 1) >= 6 and np.sum(marker_bjet[i] == 1) >= 2 :
        marker_event[i] = 1 
print("Jet selection doen.")
print("+-----------------------------------------------------------------------------------------------------+")
# Out:
# +-----------------------------------------------------------------------------------------------------+
# Start jet selection.
# Jet selection doen.
# +-----------------------------------------------------------------------------------------------------+

# %%
np.sum(marker_event == 1)
# Out:
# 286

# %%
jet_pt = []
jet_eta = []
jet_phi = []
jet_mass = []
jet_btag = []

# %%
for i in range(len(jet.event)):
    if marker_event[i] == 1:
        jet_pt_tmp = []
        jet_eta_tmp = []
        jet_phi_tmp = []
        jet_mass_tmp = []
        jet_btag_tmp = []
        for j in range(len(jet.pt[i])):
            if marker_jet[i][j] == 1:
                jet_pt_tmp.append(jet.pt[i][j])
                jet_eta_tmp.append(jet.eta[i][j])
                jet_phi_tmp.append(jet.phi[i][j])
                jet_mass_tmp.append(jet.mass[i][j])
                jet_btag_tmp.append(jet.btag[i][j])
                
        jet_pt.append(jet_pt_tmp)
        jet_eta.append(jet_eta_tmp)
        jet_phi.append(jet_phi_tmp)
        jet_mass.append(jet_mass_tmp)
        jet_btag.append(jet_btag_tmp)

# %%
jet_eta[0]
# Out:
# [0.70168823,
#  0.22287998,
#  -0.2646208,
#  -0.87214935,
#  -0.6852819,
#  0.444647,
#  -1.3317381,
#  1.6737975]

# %% [markdown]
# ## Particle tracing and daughter finding section
# ---

# %%
def shift_particle_tracing(dataset, PID_d, idx):
    if (dataset.iloc[idx,6] == PID_d):
        return dataset.iloc[idx,4]

def particle_tracing(dataset, PID, STATUS):

    for i in range(len(dataset)):
        if(dataset.iloc[i,1] == STATUS and dataset.iloc[i,6] == PID ): 
            daughter_index = int(dataset.iloc[i,0])
    if( dataset.iloc[daughter_index,6] == PID ):
        shifted_particle_index = dataset.iloc[daughter_index, 4]


    while dataset.iloc[shifted_particle_index,6] == PID:
            init_shifted_particle_index = shifted_particle_index
            shifted_particle_index = shift_particle_tracing(dataset, PID, init_shifted_particle_index)       

    dauthter_idx_1 = dataset.iloc[init_shifted_particle_index, 4]
    daughter_pid_1 = dataset.iloc[dauthter_idx_1, 6]

    dauthter_idx_2 = dataset.iloc[init_shifted_particle_index, 5]
    daughter_pid_2 = dataset.iloc[dauthter_idx_2, 6]

    return init_shifted_particle_index, dauthter_idx_1, daughter_pid_1, dauthter_idx_2, daughter_pid_2

# %%
for i in range(len(particle.event)):
    if marker_event[i] == 1:
        #print("+------------------------------------------------------------------------------------------------------+")
        #print("Start parsing event : {0}\nStart to trace top quark and find its daughters.".format(i))
        top_idx[i], top_daughter_idx_1[i], top_daughter_pid_1[i], top_daughter_idx_2[i], top_daughter_pid_2[i] = particle_tracing(particle.dataframelize(i), PID_TOP, 22)
        #print("+------------------------------------------------------~-----------------------------------------------+")
        #print("Start to find top_bar quark and its daughters.")
        top_bar_idx[i], top_bar_daughter_idx_1[i], top_bar_daughter_pid_1[i], top_bar_daughter_idx_2[i], top_bar_daughter_pid_2[i] = particle_tracing(particle.dataframelize(i), PID_TOP_BAR, 22)
        #print("+------------------------------------------------------------------------------------------------------+")

# %% [markdown]
# ### Tracing the daughter

# %%
#Input two daughter of top/top_bar and find their daughter
def quark_finder(dataset, mother_idx_1, mother_idx_2):
    
    #Specific two daughter of top
    def W_b_specifier(dataset, input_1_idx, input_2_idx):
        if dataset.iloc[int(input_1_idx),6] == PID_W_plus or dataset.iloc[int(input_1_idx),6] == PID_W_minus :
            return int(input_1_idx), int(dataset.iloc[int(input_1_idx),6]), int(input_2_idx)
        elif dataset.iloc[int(input_1_idx),6] == PID_BOTTOM or dataset.iloc[int(input_1_idx),6] == PID_BOTTOM_BAR :
            return  int(input_2_idx), int(dataset.iloc[int(input_1_idx),6]), int(input_1_idx)
        else :
            pass
            #print("Please check your data.")
    
    W_boson_idx, mother_pid, b_quark_idx = W_b_specifier(dataset, mother_idx_1, mother_idx_2)
    
    #Find the two daughters of boson
    
    daughter_1_idx = dataset.iloc[W_boson_idx, 4]
    daughter_1_pid = dataset.iloc[daughter_1_idx, 6]
    daughter_2_idx = dataset.iloc[W_boson_idx, 5]
    daughter_2_pid = dataset.iloc[daughter_2_idx, 6]

    
    if daughter_1_pid == mother_pid or daughter_2_pid == mother_pid:

        init_idx = W_boson_idx
        daughter_pid = daughter_1_pid
        if daughter_2_pid == mother_pid:
            daughter_pid = daughter_2_pid
        while daughter_pid == mother_pid :
            daughter_1_idx = dataset.iloc[int(init_idx), 4]
            daughter_2_idx = dataset.iloc[int(init_idx), 5]

            daughter_1_pid = dataset.iloc[int(daughter_1_idx), 6]
            daughter_2_pid = dataset.iloc[int(daughter_2_idx), 6]

            daughter_pid = daughter_1_pid
            init_idx = daughter_1_idx
            if daughter_2_pid == mother_pid:
                daughter_pid = daughter_2_pid
                init_idx = daughter_2_idx
            
            
            #print("Temporary daughter 1 indxe: {0}, PID: {1}".format(daughter_1_idx, daughter_1_pid))
            #print("Temporary daughter 2 indxe: {0}, PID: {1}".format(daughter_2_idx, daughter_2_pid))

    
    #print("Found daughter 1 index: {0}, PID: {1}.\nFound daughter 2 index: {2}, PID: {3}".format(daughter_1_idx, daughter_1_pid, daughter_2_idx, daughter_2_pid))
    return  b_quark_idx, daughter_1_idx, daughter_2_idx

# %%
for i in range(len(particle.event)):
    if marker_event[i] == 1 :
        #print("+------------------------------------------------------------------------------------------------------+")
        #print("Start parsing event : {0}\nStart to find top quark's daughters.".format(i))
        parton_array[i][0][0], parton_array[i][1][0], parton_array[i][2][0] = quark_finder(particle.dataframelize(i), top_daughter_idx_1[i], top_daughter_idx_2[i])
        #print("+------------------------------------------------------~-----------------------------------------------+")
        #print("Start to find top_bar quark's daughters.")
        parton_array[i][3][0], parton_array[i][4][0], parton_array[i][5][0], = quark_finder(particle.dataframelize(i), top_bar_daughter_idx_1[i], top_bar_daughter_idx_2[i])
        #print("+------------------------------------------------------------------------------------------------------+")
    elif marker_event[i] == 0 :
        parton_array[i] = 'Nan'
    else: pass

# %%
# ### 
# t t~ W+ W- b b~ 
# 0 0  0  0  0 0

# i.e.
# col 3 = 100010 
# col 5 = 101000
# col 6 = 101000
# col 8 = 010100
# col 10= 010001
# col 11= 010001

# %%
parton_pdgid = []
parton_barcode = []
parton_pt = []
parton_eta = []
parton_phi = []
parton_mass = []

# %%
barcode = np.array([34, 40, 40, 17, 20, 20])
for i in range(len(particle.event)):
    if marker_event[i] == 1:
        _parton_pdgid = []
        _parton_barcode = []
        _parton_pt = []
        _parton_eta = []
        _parton_phi = []
        _parton_mass = []
        for j in range(0,6):
            dataset = particle.dataframelize(i)

            _parton_pdgid.append(dataset.iloc[int(parton_array[i][j][0]), 6])
            _parton_barcode.append(barcode[j])
            _parton_pt.append(dataset.iloc[int(parton_array[i][j][0]), 7])
            _parton_eta.append(dataset.iloc[int(parton_array[i][j][0]), 8])
            _parton_phi.append(dataset.iloc[int(parton_array[i][j][0]), 9])
            _parton_mass.append(dataset.iloc[int(parton_array[i][j][0]), 10])

            # parton_array[i][j][1] = dataset.iloc[int(parton_array[i][j][0]), 6]  #PDGID
            # parton_array[i][j][2] = barcode[j]
            # parton_array[i][j][3] = dataset.iloc[int(parton_array[i][j][0]), 7]  #Pt
            # parton_array[i][j][4] = dataset.iloc[int(parton_array[i][j][0]), 8]  #Eta
            # parton_array[i][j][5] = dataset.iloc[int(parton_array[i][j][0]), 9]  #Phi
            # parton_array[i][j][6] = dataset.iloc[int(parton_array[i][j][0]), 10]  #Mass
        parton_pdgid.append(_parton_pdgid)
        parton_barcode.append(_parton_barcode)
        parton_pt.append(_parton_pt)
        parton_eta.append(_parton_eta)
        parton_phi.append(_parton_phi)
        parton_mass.append(_parton_mass)

# %% [markdown]
# ## Parton-jet matching section
# ---

# %% [markdown]
# ### Define the function for computing delta_R

# %%
def deltaPhi(phi1,phi2):
    phi = phi1-phi2
    while phi >= np.pi: phi -= np.pi*2.
    while phi < -np.pi: phi += np.pi*2.
    return phi

def delta_R(eta1, phi1, eta2, phi2):
    return np.sqrt(deltaPhi(phi1,phi2)**2+(eta1-eta2)**2)

# %%
dR_between_parton_jet = []
dR_between_parton_parton = []

for i in range(len(parton_pdgid)):
    dR_between_parton_jet.append(np.zeros([len(jet_pt[i]) * 6])) # # of connection = num of jet * num of parton
    dR_between_parton_parton.append(np.zeros([15])) # C^{6}_{2} = 15

dR_between_parton_jet = np.asanyarray(dR_between_parton_jet)
dR_between_parton_parton = np.asanyarray(dR_between_parton_parton)

# %%
max_num_of_jet_cand = []
for i in range(len(parton_pdgid)):
    max_num_of_jet_cand.append(len(jet_pt[i]))
max_num_of_jet_cand = np.asanyarray(max_num_of_jet_cand)
max_num_of_jet = max_num_of_jet_cand.max()
print(max_num_of_jet)

matching_jet = []
matching_parton = []
for i in range(len(parton_pdgid)):
    matching_jet.append(np.zeros([len(jet_pt[i])]))
    matching_parton.append(np.zeros([6]))

matching_jet = np.array(matching_jet)
matching_parton = np.array(matching_parton)
# Out:
# 10
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# ### Computing delta_R between each parton and jet

# %%
for i in range(len(parton_pdgid)):
    j = 0
    a = 0
    b = 0
    while a < 6 :
        for b in range( len(jet_pt[i]) ):
            #print(i, j)
            #print(i, a, b)
            #print(delta_R( parton_array[i][a][4], parton_array[i][a][5], jet.eta[i][b], jet.phi[i][b]))
            dR_between_parton_jet[i][j] = delta_R( parton_eta[i][a], parton_phi[i][a], jet_eta[i][b], jet_phi[i][b])
            j +=1
        a += 1

# %%
dR_between_parton_jet[0]
# Out:
# array([3.0795404 , 2.27719224, 0.71907042, 1.64479882, 1.3206112 ,
#        0.16871262, 1.94727524, 1.5795405 , 2.13585985, 2.9404835 ,
#        1.11541683, 2.61261277, 1.28899786, 0.95177831, 2.79791003,
#        1.12217089, 3.27738731, 2.57089229, 0.31353047, 1.31747639,
#        0.63807271, 0.97537584, 1.39827934, 2.31077201, 2.92481132,
#        2.04756577, 0.62325757, 1.11881804, 1.19858922, 0.69664669,
#        1.39848506, 2.12635636, 2.76813649, 3.22418234, 0.62649651,
#        1.91958572, 0.01989035, 1.31045454, 1.89906187, 2.35277216,
#        3.01513467, 2.68512324, 0.0150804 , 1.57501518, 0.60491233,
#        0.74487833, 1.70168691, 2.00751458])

# %% [markdown]
# ### Matching jet and parton by finding the Min(dR(parton, jet))

# %%
for i in range(len(parton_pt)):
#for i in range(0,10):

    print("+------------------------------------------------------------------------------------------------------+")
    print(i)
    #print(dR_between_parton_jet.shape)
    array = np.reshape(dR_between_parton_jet[i], [6, len(jet_pt[i])])
    #print(array.shape)
        
    dataset = pd.DataFrame({'0': array[0,:], 
                                '1': array[1,:],
                                '2': array[2,:],
                                '3': array[3,:],
                                '4': array[4,:],
                                '5': array[5,:],
                                })
    print(dataset)

    for j in range(0,6):
        print("+------------------------------------------------------------------------------------------------------+")
        min_val = dataset.stack().min()
        if min_val < 0.4:
            print("Min val: {0}".format(min_val))
            min_idx, min_col = dataset.stack().idxmin()
            matching_parton[i][j] = int(min_idx)
            matching_jet[i][j] = int(min_col)
            print("The position of minimun appears. Raw: {0}, Colume: {1}".format(min_idx, min_col))
            dataset = dataset.drop([min_col], axis=1)
            dataset = dataset.drop([min_idx], axis=0)
            print("The dataset after delete the minimun's raw and colume:")
            print(dataset)
        else:
            matching_parton[i][j] = 'Nan'
            matching_jet[i][j] = 'Nan'
    for k in range(6, len(jet_pt[i])):
        matching_jet[i][k] = 'Nan'
# Out:
# +------------------------------------------------------------------------------------------------------+
# 0
#           0         1         2         3         4         5
# 0  3.079540  2.135860  3.277387  2.924811  2.768136  3.015135
# 1  2.277192  2.940483  2.570892  2.047566  3.224182  2.685123
# 2  0.719070  1.115417  0.313530  0.623258  0.626497  0.015080
# 3  1.644799  2.612613  1.317476  1.118818  1.919586  1.575015
# 4  1.320611  1.288998  0.638073  1.198589  0.019890  0.604912
# 5  0.168713  0.951778  0.975376  0.696647  1.310455  0.744878
# 6  1.947275  2.797910  1.398279  1.398485  1.899062  1.701687
# 7  1.579541  1.122171  2.310772  2.126356  2.352772  2.007515
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.015080400711700718
# The position of minimun appears. Raw: 2, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         4
# 0  3.079540  2.135860  3.277387  2.924811  2.768136
# 1  2.277192  2.940483  2.570892  2.047566  3.224182
# 3  1.644799  2.612613  1.317476  1.118818  1.919586
# 4  1.320611  1.288998  0.638073  1.198589  0.019890
# 5  0.168713  0.951778  0.975376  0.696647  1.310455
# 6  1.947275  2.797910  1.398279  1.398485  1.899062
# 7  1.579541  1.122171  2.310772  2.126356  2.352772
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.01989034653241076
# The position of minimun appears. Raw: 4, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3
# 0  3.079540  2.135860  3.277387  2.924811
# 1  2.277192  2.940483  2.570892  2.047566
# 3  1.644799  2.612613  1.317476  1.118818
# 5  0.168713  0.951778  0.975376  0.696647
# 6  1.947275  2.797910  1.398279  1.398485
# 7  1.579541  1.122171  2.310772  2.126356
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.16871262482960694
# The position of minimun appears. Raw: 5, Colume: 0
# The dataset after delete the minimun's raw and colume:
#           1         2         3
# 0  2.135860  3.277387  2.924811
# 1  2.940483  2.570892  2.047566
# 3  2.612613  1.317476  1.118818
# 6  2.797910  1.398279  1.398485
# 7  1.122171  2.310772  2.126356
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 1
#           0         1         2         3         4         5
# 0  3.866092  2.466835  4.059306  2.707669  2.538305  2.533941
# 1  2.163454  2.000633  2.711458  3.416085  3.313651  1.254978
# 2  2.774310  0.691170  2.345828  3.015718  2.148254  2.510597
# 3  0.695674  1.794176  0.027579  2.574461  1.823631  2.027429
# 4  1.354466  3.064648  2.051850  2.180030  2.217925  0.018805
# 5  3.341031  1.487042  3.198023  2.504669  1.994019  2.266844
# 6  1.673255  1.341851  1.842114  1.064527  0.158690  2.329457
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.018804800380818446
# The position of minimun appears. Raw: 4, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         4
# 0  3.866092  2.466835  4.059306  2.707669  2.538305
# 1  2.163454  2.000633  2.711458  3.416085  3.313651
# 2  2.774310  0.691170  2.345828  3.015718  2.148254
# 3  0.695674  1.794176  0.027579  2.574461  1.823631
# 5  3.341031  1.487042  3.198023  2.504669  1.994019
# 6  1.673255  1.341851  1.842114  1.064527  0.158690
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.02757854528725198
# The position of minimun appears. Raw: 3, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         4
# 0  3.866092  2.466835  2.707669  2.538305
# 1  2.163454  2.000633  3.416085  3.313651
# 2  2.774310  0.691170  3.015718  2.148254
# 5  3.341031  1.487042  2.504669  1.994019
# 6  1.673255  1.341851  1.064527  0.158690
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.15869014120322508
# The position of minimun appears. Raw: 6, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         3
# 0  3.866092  2.466835  2.707669
# 1  2.163454  2.000633  3.416085
# 2  2.774310  0.691170  3.015718
# 5  3.341031  1.487042  2.504669
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 2
#           0         1         2         3         4         5
# 0  3.104513  2.641053  2.660034  1.713018  1.139143  0.183523
# 1  1.187541  2.098209  0.015830  1.805348  1.517197  2.802342
# 2  1.542668  0.041392  2.090254  3.154911  3.198090  2.739156
# 3  3.246814  2.977079  2.961638  1.718657  1.449782  0.314923
# 4  0.719045  0.996240  1.752037  2.248646  2.773547  2.686903
# 5  2.072787  3.195473  1.571441  1.056343  0.059695  1.239840
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.015830010924820954
# The position of minimun appears. Raw: 1, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         4         5
# 0  3.104513  2.641053  1.713018  1.139143  0.183523
# 2  1.542668  0.041392  3.154911  3.198090  2.739156
# 3  3.246814  2.977079  1.718657  1.449782  0.314923
# 4  0.719045  0.996240  2.248646  2.773547  2.686903
# 5  2.072787  3.195473  1.056343  0.059695  1.239840
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.04139223903960438
# The position of minimun appears. Raw: 2, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         3         4         5
# 0  3.104513  1.713018  1.139143  0.183523
# 3  3.246814  1.718657  1.449782  0.314923
# 4  0.719045  2.248646  2.773547  2.686903
# 5  2.072787  1.056343  0.059695  1.239840
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.05969482577827174
# The position of minimun appears. Raw: 5, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         3         5
# 0  3.104513  1.713018  0.183523
# 3  3.246814  1.718657  0.314923
# 4  0.719045  2.248646  2.686903
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.1835232831074375
# The position of minimun appears. Raw: 0, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         3
# 3  3.246814  1.718657
# 4  0.719045  2.248646
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 3
#           0         1         2         3         4         5
# 0  1.770573  0.036416  2.896460  2.473641  3.473081  1.902613
# 1  3.158527  2.297043  3.047715  1.641505  3.887954  2.958435
# 2  3.123228  2.119696  4.051994  2.604442  4.795631  3.081427
# 3  0.907790  1.558919  1.371487  2.561749  1.909474  1.163052
# 4  1.957181  1.901947  1.983640  3.384951  1.955757  2.212452
# 5  0.626773  1.927503  0.959106  2.048037  1.732366  0.850803
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.03641648514135172
# The position of minimun appears. Raw: 0, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4         5
# 1  3.158527  3.047715  1.641505  3.887954  2.958435
# 2  3.123228  4.051994  2.604442  4.795631  3.081427
# 3  0.907790  1.371487  2.561749  1.909474  1.163052
# 4  1.957181  1.983640  3.384951  1.955757  2.212452
# 5  0.626773  0.959106  2.048037  1.732366  0.850803
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 4
#           0         1         2         3         4         5
# 0  4.062387  3.301733  3.375866  1.430935  0.904940  2.973084
# 1  0.755220  1.903415  2.700235  2.445997  2.829638  1.360893
# 2  2.954975  2.096925  0.069124  1.974068  2.479896  3.410537
# 3  3.555455  2.506715  2.419761  0.545362  0.115775  2.588449
# 4  1.469224  1.395049  3.341590  2.840378  2.696838  0.164092
# 5  1.541079  0.146994  2.013153  2.404912  2.575287  1.674529
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.06912420075208098
# The position of minimun appears. Raw: 2, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         4         5
# 0  4.062387  3.301733  1.430935  0.904940  2.973084
# 1  0.755220  1.903415  2.445997  2.829638  1.360893
# 3  3.555455  2.506715  0.545362  0.115775  2.588449
# 4  1.469224  1.395049  2.840378  2.696838  0.164092
# 5  1.541079  0.146994  2.404912  2.575287  1.674529
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.11577548144923956
# The position of minimun appears. Raw: 3, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         3         5
# 0  4.062387  3.301733  1.430935  2.973084
# 1  0.755220  1.903415  2.445997  1.360893
# 4  1.469224  1.395049  2.840378  0.164092
# 5  1.541079  0.146994  2.404912  1.674529
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.14699408861041113
# The position of minimun appears. Raw: 5, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         3         5
# 0  4.062387  1.430935  2.973084
# 1  0.755220  2.445997  1.360893
# 4  1.469224  2.840378  0.164092
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.1640921621401323
# The position of minimun appears. Raw: 4, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         3
# 0  4.062387  1.430935
# 1  0.755220  2.445997
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 5
#           0         1         2         3         4         5
# 0  3.273796  3.224245  3.012321  0.605522  0.287121  0.096830
# 1  0.821298  0.083549  1.221711  3.052685  2.896307  3.223285
# 2  1.782247  1.059061  0.827593  3.082478  2.216321  2.586415
# 3  1.580418  1.054193  0.177972  2.550897  2.863688  3.059366
# 4  3.352149  2.818950  1.685855  3.134670  3.113614  3.469437
# 5  1.636451  2.114665  3.252970  4.110611  4.489864  4.480909
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.08354881086929934
# The position of minimun appears. Raw: 1, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4         5
# 0  3.273796  3.012321  0.605522  0.287121  0.096830
# 2  1.782247  0.827593  3.082478  2.216321  2.586415
# 3  1.580418  0.177972  2.550897  2.863688  3.059366
# 4  3.352149  1.685855  3.134670  3.113614  3.469437
# 5  1.636451  3.252970  4.110611  4.489864  4.480909
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.09683029612444266
# The position of minimun appears. Raw: 0, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4
# 2  1.782247  0.827593  3.082478  2.216321
# 3  1.580418  0.177972  2.550897  2.863688
# 4  3.352149  1.685855  3.134670  3.113614
# 5  1.636451  3.252970  4.110611  4.489864
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.17797248291886802
# The position of minimun appears. Raw: 3, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         3         4
# 2  1.782247  3.082478  2.216321
# 4  3.352149  3.134670  3.113614
# 5  1.636451  4.110611  4.489864
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 6
#           0         1         2         3         4         5
# 0  0.900089  0.066805  0.498266  0.803832  3.113755  2.453783
# 1  2.444394  2.501484  1.952765  2.942001  2.491784  3.023804
# 2  2.980454  2.501765  3.030677  2.121826  0.708801  0.103949
# 3  1.002693  0.571921  0.028638  1.118111  3.246940  2.946270
# 4  3.398146  3.049842  3.253458  2.767963  0.016078  0.789453
# 5  2.718124  3.196618  3.378673  3.641405  2.905999  3.088621
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.01607842899212597
# The position of minimun appears. Raw: 4, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         5
# 0  0.900089  0.066805  0.498266  0.803832  2.453783
# 1  2.444394  2.501484  1.952765  2.942001  3.023804
# 2  2.980454  2.501765  3.030677  2.121826  0.103949
# 3  1.002693  0.571921  0.028638  1.118111  2.946270
# 5  2.718124  3.196618  3.378673  3.641405  3.088621
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.02863763829729333
# The position of minimun appears. Raw: 3, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         5
# 0  0.900089  0.066805  0.803832  2.453783
# 1  2.444394  2.501484  2.942001  3.023804
# 2  2.980454  2.501765  2.121826  0.103949
# 5  2.718124  3.196618  3.641405  3.088621
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.06680472020248183
# The position of minimun appears. Raw: 0, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         3         5
# 1  2.444394  2.942001  3.023804
# 2  2.980454  2.121826  0.103949
# 5  2.718124  3.641405  3.088621
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.10394922302555085
# The position of minimun appears. Raw: 2, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         3
# 1  2.444394  2.942001
# 5  2.718124  3.641405
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 7
#           0         1         2         3         4         5
# 0  2.563680  1.798641  1.835580  1.051510  1.022279  0.240703
# 1  1.592316  1.750420  2.476046  1.447984  2.820618  1.998230
# 2  1.332073  2.940813  0.014140  2.878912  2.012959  1.996405
# 3  3.654179  1.711178  2.308852  3.218398  3.363738  2.357226
# 4  1.093474  2.300509  2.179258  1.796051  3.176275  2.492220
# 5  2.212373  2.782268  2.076859  1.316116  0.078540  1.213675
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.014139592943411106
# The position of minimun appears. Raw: 2, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         4         5
# 0  2.563680  1.798641  1.051510  1.022279  0.240703
# 1  1.592316  1.750420  1.447984  2.820618  1.998230
# 3  3.654179  1.711178  3.218398  3.363738  2.357226
# 4  1.093474  2.300509  1.796051  3.176275  2.492220
# 5  2.212373  2.782268  1.316116  0.078540  1.213675
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.07853986843709994
# The position of minimun appears. Raw: 5, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         3         5
# 0  2.563680  1.798641  1.051510  0.240703
# 1  1.592316  1.750420  1.447984  1.998230
# 3  3.654179  1.711178  3.218398  2.357226
# 4  1.093474  2.300509  1.796051  2.492220
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.24070305665156846
# The position of minimun appears. Raw: 0, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         3
# 1  1.592316  1.750420  1.447984
# 3  3.654179  1.711178  3.218398
# 4  1.093474  2.300509  1.796051
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 8
#           0         1         2         3         4         5
# 0  3.149581  0.603550  1.701497  0.931103  1.584544  2.923640
# 1  1.752561  2.123706  3.150187  2.193001  0.046727  1.905609
# 2  2.465137  0.158637  1.221188  0.686300  2.299217  2.202966
# 3  1.977741  1.379020  0.015046  1.884237  3.183373  1.861102
# 4  1.794689  3.680289  2.729886  4.081565  2.471614  2.103569
# 5  2.712163  3.581885  4.225174  3.316750  2.047230  2.583816
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.015046031832147595
# The position of minimun appears. Raw: 3, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         4         5
# 0  3.149581  0.603550  0.931103  1.584544  2.923640
# 1  1.752561  2.123706  2.193001  0.046727  1.905609
# 2  2.465137  0.158637  0.686300  2.299217  2.202966
# 4  1.794689  3.680289  4.081565  2.471614  2.103569
# 5  2.712163  3.581885  3.316750  2.047230  2.583816
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.046726994278036366
# The position of minimun appears. Raw: 1, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         3         5
# 0  3.149581  0.603550  0.931103  2.923640
# 2  2.465137  0.158637  0.686300  2.202966
# 4  1.794689  3.680289  4.081565  2.103569
# 5  2.712163  3.581885  3.316750  2.583816
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.15863724887776548
# The position of minimun appears. Raw: 2, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         3         5
# 0  3.149581  0.931103  2.923640
# 4  1.794689  4.081565  2.103569
# 5  2.712163  3.316750  2.583816
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 9
#           0         1         2         3         4         5
# 0  2.383367  1.821206  3.026083  2.467620  1.816561  0.025715
# 1  2.430758  0.116765  1.514507  2.277920  3.027768  1.905828
# 2  0.926241  1.618760  0.023216  1.174362  1.529621  2.992980
# 3  4.226245  2.419156  3.520351  3.553337  4.711961  3.611546
# 4  0.838696  1.918079  0.627623  0.545433  1.340349  2.906769
# 5  1.624281  2.635477  2.300028  1.254910  1.327650  1.383087
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.02321649066166458
# The position of minimun appears. Raw: 2, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         4         5
# 0  2.383367  1.821206  2.467620  1.816561  0.025715
# 1  2.430758  0.116765  2.277920  3.027768  1.905828
# 3  4.226245  2.419156  3.553337  4.711961  3.611546
# 4  0.838696  1.918079  0.545433  1.340349  2.906769
# 5  1.624281  2.635477  1.254910  1.327650  1.383087
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.02571533459799728
# The position of minimun appears. Raw: 0, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         3         4
# 1  2.430758  0.116765  2.277920  3.027768
# 3  4.226245  2.419156  3.553337  4.711961
# 4  0.838696  1.918079  0.545433  1.340349
# 5  1.624281  2.635477  1.254910  1.327650
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.11676453745132771
# The position of minimun appears. Raw: 1, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         3         4
# 3  4.226245  3.553337  4.711961
# 4  0.838696  0.545433  1.340349
# 5  1.624281  1.254910  1.327650
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 10
#           0         1         2         3         4         5
# 0  3.158226  1.885432  3.189749  3.680127  1.029268  1.991035
# 1  1.223374  2.739599  1.739870  0.859061  3.304123  1.264744
# 2  1.495905  3.144398  2.845795  1.861888  2.099676  0.145012
# 3  0.692177  1.782859  0.956039  0.142787  2.662899  1.776393
# 4  2.993536  1.753078  2.786925  3.412567  0.665477  1.674696
# 5  3.260734  2.156169  3.567888  3.847168  1.433435  2.230232
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.1427865095201692
# The position of minimun appears. Raw: 3, Colume: 3
# The dataset after delete the minimun's raw and colume:
#           0         1         2         4         5
# 0  3.158226  1.885432  3.189749  1.029268  1.991035
# 1  1.223374  2.739599  1.739870  3.304123  1.264744
# 2  1.495905  3.144398  2.845795  2.099676  0.145012
# 4  2.993536  1.753078  2.786925  0.665477  1.674696
# 5  3.260734  2.156169  3.567888  1.433435  2.230232
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.145011980967845
# The position of minimun appears. Raw: 2, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         2         4
# 0  3.158226  1.885432  3.189749  1.029268
# 1  1.223374  2.739599  1.739870  3.304123
# 4  2.993536  1.753078  2.786925  0.665477
# 5  3.260734  2.156169  3.567888  1.433435
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 11
#           0         1         2         3         4         5
# 0  0.980377  2.325580  0.011251  2.561400  2.393307  2.593083
# 1  2.588862  1.630945  2.119491  2.393093  3.346390  3.193929
# 2  3.372543  1.904373  2.414057  2.981707  2.886106  0.290263
# 3  3.099007  2.512420  3.103392  2.047664  1.046299  2.341384
# 4  2.229732  1.974877  2.468118  1.094044  0.067664  2.544364
# 5  3.823564  1.539245  2.833855  2.321308  2.109821  0.499907
# 6  0.537003  2.936860  1.009663  2.433259  2.690803  3.553194
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.011250915391014072
# The position of minimun appears. Raw: 0, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         4         5
# 1  2.588862  1.630945  2.393093  3.346390  3.193929
# 2  3.372543  1.904373  2.981707  2.886106  0.290263
# 3  3.099007  2.512420  2.047664  1.046299  2.341384
# 4  2.229732  1.974877  1.094044  0.067664  2.544364
# 5  3.823564  1.539245  2.321308  2.109821  0.499907
# 6  0.537003  2.936860  2.433259  2.690803  3.553194
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.06766350175621255
# The position of minimun appears. Raw: 4, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         3         5
# 1  2.588862  1.630945  2.393093  3.193929
# 2  3.372543  1.904373  2.981707  0.290263
# 3  3.099007  2.512420  2.047664  2.341384
# 5  3.823564  1.539245  2.321308  0.499907
# 6  0.537003  2.936860  2.433259  3.553194
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.2902627852291036
# The position of minimun appears. Raw: 2, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         3
# 1  2.588862  1.630945  2.393093
# 3  3.099007  2.512420  2.047664
# 5  3.823564  1.539245  2.321308
# 6  0.537003  2.936860  2.433259
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 12
#           0         1         2         3         4         5
# 0  0.780166  0.075669  0.964645  2.716365  2.757246  3.240932
# 1  2.556628  2.858307  2.151506  1.219404  0.028219  0.998025
# 2  3.272713  3.574241  3.043685  1.286488  1.096843  0.458908
# 3  3.143911  3.471222  2.736833  0.929826  0.645277  0.388373
# 4  2.778142  3.026327  3.137080  0.781864  1.175098  0.169146
# 5  3.084456  3.603791  2.694753  1.849578  1.173686  1.078373
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.02821899064597793
# The position of minimun appears. Raw: 1, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         5
# 0  0.780166  0.075669  0.964645  2.716365  3.240932
# 2  3.272713  3.574241  3.043685  1.286488  0.458908
# 3  3.143911  3.471222  2.736833  0.929826  0.388373
# 4  2.778142  3.026327  3.137080  0.781864  0.169146
# 5  3.084456  3.603791  2.694753  1.849578  1.078373
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.07566897778763312
# The position of minimun appears. Raw: 0, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         5
# 2  3.272713  3.043685  1.286488  0.458908
# 3  3.143911  2.736833  0.929826  0.388373
# 4  2.778142  3.137080  0.781864  0.169146
# 5  3.084456  2.694753  1.849578  1.078373
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.16914578520972406
# The position of minimun appears. Raw: 4, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         2         3
# 2  3.272713  3.043685  1.286488
# 3  3.143911  2.736833  0.929826
# 5  3.084456  2.694753  1.849578
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 13
#           0         1         2         3         4         5
# 0  2.101178  2.389492  2.161815  1.985873  0.459545  0.004939
# 1  2.491969  2.870115  2.882660  2.589368  1.704960  1.967827
# 2  2.629652  2.622348  3.185111  2.688322  1.572957  1.678449
# 3  2.114438  3.348351  1.882996  2.281071  3.349066  3.704060
# 4  2.452503  3.808079  2.015776  2.621675  3.861151  4.177559
# 5  1.946886  3.418264  1.340265  2.109242  3.255314  3.466238
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.004939097908926426
# The position of minimun appears. Raw: 0, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         4
# 1  2.491969  2.870115  2.882660  2.589368  1.704960
# 2  2.629652  2.622348  3.185111  2.688322  1.572957
# 3  2.114438  3.348351  1.882996  2.281071  3.349066
# 4  2.452503  3.808079  2.015776  2.621675  3.861151
# 5  1.946886  3.418264  1.340265  2.109242  3.255314
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 14
#           0         1         2         3         4         5
# 0  2.753688  0.998103  2.943482  2.273270  0.089535  2.050001
# 1  2.704493  1.069073  2.707059  2.191661  0.603113  2.510002
# 2  2.699001  2.325458  2.385353  3.187390  1.299175  0.810397
# 3  1.758782  0.003829  2.857898  1.281200  1.059293  2.971014
# 4  2.347573  2.381204  1.912878  2.853459  1.319343  1.200083
# 5  2.778170  3.010766  2.799275  3.202277  2.052655  0.057906
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.003829244710955306
# The position of minimun appears. Raw: 3, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4         5
# 0  2.753688  2.943482  2.273270  0.089535  2.050001
# 1  2.704493  2.707059  2.191661  0.603113  2.510002
# 2  2.699001  2.385353  3.187390  1.299175  0.810397
# 4  2.347573  1.912878  2.853459  1.319343  1.200083
# 5  2.778170  2.799275  3.202277  2.052655  0.057906
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.05790635856318734
# The position of minimun appears. Raw: 5, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4
# 0  2.753688  2.943482  2.273270  0.089535
# 1  2.704493  2.707059  2.191661  0.603113
# 2  2.699001  2.385353  3.187390  1.299175
# 4  2.347573  1.912878  2.853459  1.319343
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.08953457308209035
# The position of minimun appears. Raw: 0, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         2         3
# 1  2.704493  2.707059  2.191661
# 2  2.699001  2.385353  3.187390
# 4  2.347573  1.912878  2.853459
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 15
#           0         1         2         3         4         5
# 0  1.027782  1.023176  0.050344  1.813015  3.144448  2.248664
# 1  3.948429  2.602435  2.954075  2.960220  1.300203  2.450825
# 2  1.736520  0.027315  1.045612  2.807178  2.427896  3.225721
# 3  3.226333  2.392688  3.157431  1.765006  0.045337  1.440202
# 4  2.014569  3.069300  2.012512  0.592340  1.524934  0.210943
# 5  4.110822  3.010283  3.484610  2.590572  1.133349  1.985618
# 6  3.159455  1.939008  2.961107  2.760758  2.644300  3.232675
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.027315152994947006
# The position of minimun appears. Raw: 2, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4         5
# 0  1.027782  0.050344  1.813015  3.144448  2.248664
# 1  3.948429  2.954075  2.960220  1.300203  2.450825
# 3  3.226333  3.157431  1.765006  0.045337  1.440202
# 4  2.014569  2.012512  0.592340  1.524934  0.210943
# 5  4.110822  3.484610  2.590572  1.133349  1.985618
# 6  3.159455  2.961107  2.760758  2.644300  3.232675
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.04533701786683302
# The position of minimun appears. Raw: 3, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         2         3         5
# 0  1.027782  0.050344  1.813015  2.248664
# 1  3.948429  2.954075  2.960220  2.450825
# 4  2.014569  2.012512  0.592340  0.210943
# 5  4.110822  3.484610  2.590572  1.985618
# 6  3.159455  2.961107  2.760758  3.232675
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.050344167046376204
# The position of minimun appears. Raw: 0, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         3         5
# 1  3.948429  2.960220  2.450825
# 4  2.014569  0.592340  0.210943
# 5  4.110822  2.590572  1.985618
# 6  3.159455  2.760758  3.232675
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.2109426215214803
# The position of minimun appears. Raw: 4, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         3
# 1  3.948429  2.960220
# 5  4.110822  2.590572
# 6  3.159455  2.760758
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 16
#           0         1         2         3         4         5
# 0  1.093527  1.478727  2.638284  2.172289  0.065613  2.879548
# 1  2.370321  1.166318  0.178451  1.877737  2.615049  3.004035
# 2  0.752212  2.355245  2.762932  2.010459  1.796326  4.475099
# 3  3.871564  2.454808  2.559620  2.463451  3.154739  1.668146
# 4  2.873798  1.341075  0.839829  1.633214  2.884633  2.543444
# 5  0.632317  1.493360  1.850523  2.666994  1.535578  3.745629
# 6  2.956041  2.639021  1.511495  2.259919  3.695828  4.693787
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.06561270721121176
# The position of minimun appears. Raw: 0, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         5
# 1  2.370321  1.166318  0.178451  1.877737  3.004035
# 2  0.752212  2.355245  2.762932  2.010459  4.475099
# 3  3.871564  2.454808  2.559620  2.463451  1.668146
# 4  2.873798  1.341075  0.839829  1.633214  2.543444
# 5  0.632317  1.493360  1.850523  2.666994  3.745629
# 6  2.956041  2.639021  1.511495  2.259919  4.693787
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.1784511801643597
# The position of minimun appears. Raw: 1, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         5
# 2  0.752212  2.355245  2.010459  4.475099
# 3  3.871564  2.454808  2.463451  1.668146
# 4  2.873798  1.341075  1.633214  2.543444
# 5  0.632317  1.493360  2.666994  3.745629
# 6  2.956041  2.639021  2.259919  4.693787
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 17
#           0         1         2         3         4         5
# 0  2.441280  2.387346  2.721456  2.085758  2.366901  2.798123
# 1  2.900921  1.045628  2.512332  0.546886  2.883532  2.747233
# 2  2.274345  2.759605  1.458874  2.260149  2.103459  2.406292
# 3  2.674138  2.878093  2.798365  2.558325  2.555308  3.068549
# 4  2.998563  0.017796  3.442608  0.516592  3.147551  3.021966
# 5  0.927086  3.435135  0.025485  2.997045  0.700639  1.225132
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.017795847020649323
# The position of minimun appears. Raw: 4, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4         5
# 0  2.441280  2.721456  2.085758  2.366901  2.798123
# 1  2.900921  2.512332  0.546886  2.883532  2.747233
# 2  2.274345  1.458874  2.260149  2.103459  2.406292
# 3  2.674138  2.798365  2.558325  2.555308  3.068549
# 5  0.927086  0.025485  2.997045  0.700639  1.225132
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.02548454643147576
# The position of minimun appears. Raw: 5, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         3         4         5
# 0  2.441280  2.085758  2.366901  2.798123
# 1  2.900921  0.546886  2.883532  2.747233
# 2  2.274345  2.260149  2.103459  2.406292
# 3  2.674138  2.558325  2.555308  3.068549
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 18
#           0         1         2         3         4         5
# 0  2.680966  2.533563  3.446851  2.346181  0.900742  3.215848
# 1  1.306088  0.032365  1.287217  1.450300  2.935247  2.074025
# 2  2.589495  3.047894  1.818182  2.681686  3.159053  4.383090
# 3  2.626681  1.972330  3.150972  3.207532  1.811846  2.655713
# 4  3.489145  2.958369  2.968616  1.477515  0.008610  2.366928
# 5  0.679863  1.004062  0.375672  1.756366  3.122561  2.944731
# 6  3.362609  2.071034  3.092953  1.740749  2.422923  0.055288
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.008609601576634478
# The position of minimun appears. Raw: 4, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         5
# 0  2.680966  2.533563  3.446851  2.346181  3.215848
# 1  1.306088  0.032365  1.287217  1.450300  2.074025
# 2  2.589495  3.047894  1.818182  2.681686  4.383090
# 3  2.626681  1.972330  3.150972  3.207532  2.655713
# 5  0.679863  1.004062  0.375672  1.756366  2.944731
# 6  3.362609  2.071034  3.092953  1.740749  0.055288
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.03236501793945953
# The position of minimun appears. Raw: 1, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         5
# 0  2.680966  3.446851  2.346181  3.215848
# 2  2.589495  1.818182  2.681686  4.383090
# 3  2.626681  3.150972  3.207532  2.655713
# 5  0.679863  0.375672  1.756366  2.944731
# 6  3.362609  3.092953  1.740749  0.055288
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.05528765576943946
# The position of minimun appears. Raw: 6, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         2         3
# 0  2.680966  3.446851  2.346181
# 2  2.589495  1.818182  2.681686
# 3  2.626681  3.150972  3.207532
# 5  0.679863  0.375672  1.756366
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.3756724565027342
# The position of minimun appears. Raw: 5, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         3
# 0  2.680966  2.346181
# 2  2.589495  2.681686
# 3  2.626681  3.207532
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 19
#           0         1         2         3         4         5
# 0  2.783208  1.259859  2.637506  3.195947  4.186931  3.998361
# 1  3.903669  3.701277  3.485810  1.103789  2.639118  0.030784
# 2  2.160877  0.129161  1.774644  3.185457  3.236369  3.697054
# 3  0.647615  1.763658  0.100885  2.445674  3.763556  3.456707
# 4  1.781643  0.412423  1.294014  3.391084  3.069250  3.929635
# 5  4.352179  3.150628  3.652458  3.300748  0.058371  2.702171
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.030783791259628667
# The position of minimun appears. Raw: 1, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         4
# 0  2.783208  1.259859  2.637506  3.195947  4.186931
# 2  2.160877  0.129161  1.774644  3.185457  3.236369
# 3  0.647615  1.763658  0.100885  2.445674  3.763556
# 4  1.781643  0.412423  1.294014  3.391084  3.069250
# 5  4.352179  3.150628  3.652458  3.300748  0.058371
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.05837099454896812
# The position of minimun appears. Raw: 5, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3
# 0  2.783208  1.259859  2.637506  3.195947
# 2  2.160877  0.129161  1.774644  3.185457
# 3  0.647615  1.763658  0.100885  2.445674
# 4  1.781643  0.412423  1.294014  3.391084
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.10088525820131093
# The position of minimun appears. Raw: 3, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3
# 0  2.783208  1.259859  3.195947
# 2  2.160877  0.129161  3.185457
# 4  1.781643  0.412423  3.391084
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.12916060818399405
# The position of minimun appears. Raw: 2, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         3
# 0  2.783208  3.195947
# 4  1.781643  3.391084
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 20
#           0         1         2         3         4         5
# 0  3.400574  2.889257  3.004971  3.806103  2.716562  3.381981
# 1  2.187577  0.577613  1.964645  1.323798  0.040551  1.902372
# 2  0.034779  2.568769  1.218218  0.907399  2.257078  2.818041
# 3  1.166645  2.506305  0.024629  1.000627  2.002499  3.647413
# 4  3.030212  1.250232  3.712681  2.847692  1.813271  0.180240
# 5  2.359546  2.109017  2.393432  3.026074  2.198330  2.185314
# 6  2.526750  0.018416  2.481429  1.716682  0.548248  1.348439
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.0184158805825349
# The position of minimun appears. Raw: 6, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4         5
# 0  3.400574  3.004971  3.806103  2.716562  3.381981
# 1  2.187577  1.964645  1.323798  0.040551  1.902372
# 2  0.034779  1.218218  0.907399  2.257078  2.818041
# 3  1.166645  0.024629  1.000627  2.002499  3.647413
# 4  3.030212  3.712681  2.847692  1.813271  0.180240
# 5  2.359546  2.393432  3.026074  2.198330  2.185314
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.02462901493011663
# The position of minimun appears. Raw: 3, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         3         4         5
# 0  3.400574  3.806103  2.716562  3.381981
# 1  2.187577  1.323798  0.040551  1.902372
# 2  0.034779  0.907399  2.257078  2.818041
# 4  3.030212  2.847692  1.813271  0.180240
# 5  2.359546  3.026074  2.198330  2.185314
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.03477907212350762
# The position of minimun appears. Raw: 2, Colume: 0
# The dataset after delete the minimun's raw and colume:
#           3         4         5
# 0  3.806103  2.716562  3.381981
# 1  1.323798  0.040551  1.902372
# 4  2.847692  1.813271  0.180240
# 5  3.026074  2.198330  2.185314
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.040550835318369366
# The position of minimun appears. Raw: 1, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           3         5
# 0  3.806103  3.381981
# 4  2.847692  0.180240
# 5  3.026074  2.185314
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.18024017662292702
# The position of minimun appears. Raw: 4, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           3
# 0  3.806103
# 5  3.026074
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 21
# ...
# Min val: 0.04379725751326184
# The position of minimun appears. Raw: 3, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         2         3         5
# 0  0.070193  0.439334  0.433741  2.992239
# 1  2.842602  2.678901  2.542971  1.018395
# 2  2.212093  2.083076  1.892886  1.301688
# 4  1.315445  1.182854  1.060433  2.146574
# 5  2.687468  3.054458  2.794329  2.765267
# 7  1.741060  2.148369  1.534186  3.606084
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.07019348313504689
# The position of minimun appears. Raw: 0, Colume: 0
# The dataset after delete the minimun's raw and colume:
#           2         3         5
# 1  2.678901  2.542971  1.018395
# 2  2.083076  1.892886  1.301688
# 4  1.182854  1.060433  2.146574
# 5  3.054458  2.794329  2.765267
# 7  2.148369  1.534186  3.606084
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 280
#           0         1         2         3         4         5
# 0  2.521775  3.628580  3.118578  3.802729  2.587167  2.368306
# 1  0.039741  1.513334  0.560741  1.364550  1.541225  3.279216
# 2  0.945658  0.614446  0.463624  0.460167  1.270030  2.547930
# 3  2.418931  1.458841  1.851554  1.658273  0.983337  0.999055
# 4  2.178043  3.697058  2.775448  3.518508  3.056569  2.681337
# 5  0.954858  1.170643  0.525956  1.163575  0.612367  2.460029
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.03974132765715697
# The position of minimun appears. Raw: 1, Colume: 0
# The dataset after delete the minimun's raw and colume:
#           1         2         3         4         5
# 0  3.628580  3.118578  3.802729  2.587167  2.368306
# 2  0.614446  0.463624  0.460167  1.270030  2.547930
# 3  1.458841  1.851554  1.658273  0.983337  0.999055
# 4  3.697058  2.775448  3.518508  3.056569  2.681337
# 5  1.170643  0.525956  1.163575  0.612367  2.460029
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 281
#           0         1         2         3         4         5
# 0  1.534780  2.360277  1.458840  2.785526  1.935136  0.860020
# 1  2.735706  0.009273  1.348360  1.606025  2.170732  2.533395
# 2  2.195386  2.402457  1.912772  2.985521  2.225009  0.137389
# 3  2.375704  1.274845  0.073975  2.844017  3.255066  2.032340
# 4  1.261262  2.291217  3.137450  0.958260  0.116821  2.070806
# 5  3.122181  3.506359  3.254210  3.023119  2.561596  1.221361
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.00927346456020565
# The position of minimun appears. Raw: 1, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4         5
# 0  1.534780  1.458840  2.785526  1.935136  0.860020
# 2  2.195386  1.912772  2.985521  2.225009  0.137389
# 3  2.375704  0.073975  2.844017  3.255066  2.032340
# 4  1.261262  3.137450  0.958260  0.116821  2.070806
# 5  3.122181  3.254210  3.023119  2.561596  1.221361
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.07397525196492671
# The position of minimun appears. Raw: 3, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         3         4         5
# 0  1.534780  2.785526  1.935136  0.860020
# 2  2.195386  2.985521  2.225009  0.137389
# 4  1.261262  0.958260  0.116821  2.070806
# 5  3.122181  3.023119  2.561596  1.221361
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.11682126807246282
# The position of minimun appears. Raw: 4, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         3         5
# 0  1.534780  2.785526  0.860020
# 2  2.195386  2.985521  0.137389
# 5  3.122181  3.023119  1.221361
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.13738948061823322
# The position of minimun appears. Raw: 2, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         3
# 0  1.534780  2.785526
# 5  3.122181  3.023119
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 282
#           0         1         2         3         4         5
# 0  1.258957  1.611758  3.140398  2.447334  1.958450  0.040012
# 1  2.564615  0.041370  1.519364  2.403943  2.970415  1.632202
# 2  1.190537  2.982226  2.519527  0.672612  0.012294  1.996994
# 3  0.102665  2.512916  2.775062  1.429708  1.264701  1.332954
# 4  1.880336  0.657243  2.114041  3.073641  2.867424  1.026664
# 5  3.791686  2.831401  2.176962  4.015486  4.683053  3.797661
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.012293784897821338
# The position of minimun appears. Raw: 2, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         5
# 0  1.258957  1.611758  3.140398  2.447334  0.040012
# 1  2.564615  0.041370  1.519364  2.403943  1.632202
# 3  0.102665  2.512916  2.775062  1.429708  1.332954
# 4  1.880336  0.657243  2.114041  3.073641  1.026664
# 5  3.791686  2.831401  2.176962  4.015486  3.797661
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.040011985421942675
# The position of minimun appears. Raw: 0, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3
# 1  2.564615  0.041370  1.519364  2.403943
# 3  0.102665  2.512916  2.775062  1.429708
# 4  1.880336  0.657243  2.114041  3.073641
# 5  3.791686  2.831401  2.176962  4.015486
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.04136954275676796
# The position of minimun appears. Raw: 1, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3
# 3  0.102665  2.775062  1.429708
# 4  1.880336  2.114041  3.073641
# 5  3.791686  2.176962  4.015486
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.10266467973547225
# The position of minimun appears. Raw: 3, Colume: 0
# The dataset after delete the minimun's raw and colume:
#           2         3
# 4  2.114041  3.073641
# 5  2.176962  4.015486
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 283
#           0         1         2         3         4         5
# 0  0.103443  2.628946  0.773984  2.938573  1.998548  3.726991
# 1  2.779197  0.051133  1.909179  1.256428  1.727928  1.631789
# 2  1.500899  3.253530  2.346799  2.684061  3.514914  3.697473
# 3  2.424668  4.608102  2.988407  4.262262  4.476574  5.280234
# 4  0.870243  1.859929  0.037130  3.159116  1.524991  3.406080
# 5  2.111685  1.706438  1.583396  2.806608  0.029192  2.555949
# 6  2.414888  0.496357  1.546876  1.648353  1.810044  2.149182
# 7  2.697902  3.661546  2.701788  4.542863  4.218132  5.281846
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.029192002168244916
# The position of minimun appears. Raw: 5, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         5
# 0  0.103443  2.628946  0.773984  2.938573  3.726991
# 1  2.779197  0.051133  1.909179  1.256428  1.631789
# 2  1.500899  3.253530  2.346799  2.684061  3.697473
# 3  2.424668  4.608102  2.988407  4.262262  5.280234
# 4  0.870243  1.859929  0.037130  3.159116  3.406080
# 6  2.414888  0.496357  1.546876  1.648353  2.149182
# 7  2.697902  3.661546  2.701788  4.542863  5.281846
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.03712973449202441
# The position of minimun appears. Raw: 4, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0         1         3         5
# 0  0.103443  2.628946  2.938573  3.726991
# 1  2.779197  0.051133  1.256428  1.631789
# 2  1.500899  3.253530  2.684061  3.697473
# 3  2.424668  4.608102  4.262262  5.280234
# 6  2.414888  0.496357  1.648353  2.149182
# 7  2.697902  3.661546  4.542863  5.281846
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.05113257306156078
# The position of minimun appears. Raw: 1, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         3         5
# 0  0.103443  2.938573  3.726991
# 2  1.500899  2.684061  3.697473
# 3  2.424668  4.262262  5.280234
# 6  2.414888  1.648353  2.149182
# 7  2.697902  4.542863  5.281846
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.10344316868306065
# The position of minimun appears. Raw: 0, Colume: 0
# The dataset after delete the minimun's raw and colume:
#           3         5
# 2  2.684061  3.697473
# 3  4.262262  5.280234
# 6  1.648353  2.149182
# 7  4.542863  5.281846
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 284
#           0         1         2         3         4         5
# 0  1.932260  2.786586  3.499488  1.129485  2.524903  2.138647
# 1  3.891015  4.725968  5.639723  1.244305  1.081609  0.063954
# 2  0.068103  0.982068  2.136899  3.048762  3.422541  3.883166
# 3  2.371005  2.381421  3.552655  1.581173  1.765165  2.509985
# 4  3.294723  3.754386  5.055188  1.462749  0.082429  1.222390
# 5  1.444164  2.410358  3.345375  1.692176  3.041908  2.428604
# 6  2.754963  3.645945  4.349873  0.363427  1.690374  1.315625
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.06395423436290423
# The position of minimun appears. Raw: 1, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         1         2         3         4
# 0  1.932260  2.786586  3.499488  1.129485  2.524903
# 2  0.068103  0.982068  2.136899  3.048762  3.422541
# 3  2.371005  2.381421  3.552655  1.581173  1.765165
# 4  3.294723  3.754386  5.055188  1.462749  0.082429
# 5  1.444164  2.410358  3.345375  1.692176  3.041908
# 6  2.754963  3.645945  4.349873  0.363427  1.690374
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.06810335564834541
# The position of minimun appears. Raw: 2, Colume: 0
# The dataset after delete the minimun's raw and colume:
#           1         2         3         4
# 0  2.786586  3.499488  1.129485  2.524903
# 3  2.381421  3.552655  1.581173  1.765165
# 4  3.754386  5.055188  1.462749  0.082429
# 5  2.410358  3.345375  1.692176  3.041908
# 6  3.645945  4.349873  0.363427  1.690374
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.08242893032819192
# The position of minimun appears. Raw: 4, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           1         2         3
# 0  2.786586  3.499488  1.129485
# 3  2.381421  3.552655  1.581173
# 5  2.410358  3.345375  1.692176
# 6  3.645945  4.349873  0.363427
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.36342672543987503
# The position of minimun appears. Raw: 6, Colume: 3
# The dataset after delete the minimun's raw and colume:
#           1         2
# 0  2.786586  3.499488
# 3  2.381421  3.552655
# 5  2.410358  3.345375
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------+
# 285
#           0         1         2         3         4         5
# 0  2.797241  2.683575  2.196517  0.209842  1.081321  0.562336
# 1  1.737775  2.569667  3.217679  1.162071  0.043085  1.055443
# 2  1.058941  0.012488  2.257702  2.756755  2.609682  2.720213
# 3  2.232597  2.090871  0.210226  1.945588  3.056530  2.492583
# 4  2.709237  2.815942  2.759511  0.825419  0.940364  0.107538
# 5  0.924714  0.591277  2.747636  3.226641  2.116324  3.027949
# 6  2.343138  2.452395  0.404749  2.479929  3.570405  3.066112
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.012488112237933476
# The position of minimun appears. Raw: 2, Colume: 1
# The dataset after delete the minimun's raw and colume:
#           0         2         3         4         5
# 0  2.797241  2.196517  0.209842  1.081321  0.562336
# 1  1.737775  3.217679  1.162071  0.043085  1.055443
# 3  2.232597  0.210226  1.945588  3.056530  2.492583
# 4  2.709237  2.759511  0.825419  0.940364  0.107538
# 5  0.924714  2.747636  3.226641  2.116324  3.027949
# 6  2.343138  0.404749  2.479929  3.570405  3.066112
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.04308531105694739
# The position of minimun appears. Raw: 1, Colume: 4
# The dataset after delete the minimun's raw and colume:
#           0         2         3         5
# 0  2.797241  2.196517  0.209842  0.562336
# 3  2.232597  0.210226  1.945588  2.492583
# 4  2.709237  2.759511  0.825419  0.107538
# 5  0.924714  2.747636  3.226641  3.027949
# 6  2.343138  0.404749  2.479929  3.066112
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.10753844130062254
# The position of minimun appears. Raw: 4, Colume: 5
# The dataset after delete the minimun's raw and colume:
#           0         2         3
# 0  2.797241  2.196517  0.209842
# 3  2.232597  0.210226  1.945588
# 5  0.924714  2.747636  3.226641
# 6  2.343138  0.404749  2.479929
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.20984243189107193
# The position of minimun appears. Raw: 0, Colume: 3
# The dataset after delete the minimun's raw and colume:
#           0         2
# 3  2.232597  0.210226
# 5  0.924714  2.747636
# 6  2.343138  0.404749
# +------------------------------------------------------------------------------------------------------+
# Min val: 0.21022612038571983
# The position of minimun appears. Raw: 3, Colume: 2
# The dataset after delete the minimun's raw and colume:
#           0
# 5  0.924714
# 6  2.343138
# +------------------------------------------------------------------------------------------------------+

# %%
for i in range(len(parton_pdgid)):
    print(i)
    array = np.reshape(dR_between_parton_jet[i], [6, len(jet_pt[i])])
    print(matching_parton[i], matching_jet[i])
# Out:
# 0
# [ 2.  4.  5. nan nan nan] [ 5.  4.  0. nan nan nan nan nan]
# 1
# [ 4.  3.  6. nan nan nan] [ 5.  2.  4. nan nan nan nan]
# 2
# [ 1.  2.  5.  0. nan nan] [ 2.  1.  4.  5. nan nan]
# 3
# [ 0. nan nan nan nan nan] [ 1. nan nan nan nan nan]
# 4
# [ 2.  3.  5.  4. nan nan] [ 2.  4.  1.  5. nan nan]
# 5
# [ 1.  0.  3. nan nan nan] [ 1.  5.  2. nan nan nan]
# 6
# [ 4.  3.  0.  2. nan nan] [ 4.  2.  1.  5. nan nan]
# 7
# [ 2.  5.  0. nan nan nan] [ 2.  4.  5. nan nan nan]
# 8
# [ 3.  1.  2. nan nan nan] [ 2.  4.  1. nan nan nan]
# 9
# [ 2.  0.  1. nan nan nan] [ 2.  5.  1. nan nan nan]
# 10
# [ 3.  2. nan nan nan nan] [ 3.  5. nan nan nan nan]
# 11
# [ 0.  4.  2. nan nan nan] [ 2.  4.  5. nan nan nan nan]
# 12
# [ 1.  0.  4. nan nan nan] [ 4.  1.  5. nan nan nan]
# 13
# [ 0. nan nan nan nan nan] [ 5. nan nan nan nan nan]
# 14
# [ 3.  5.  0. nan nan nan] [ 1.  5.  4. nan nan nan]
# 15
# [ 2.  3.  0.  4. nan nan] [ 1.  4.  2.  5. nan nan nan]
# 16
# [ 0.  1. nan nan nan nan] [ 4.  2. nan nan nan nan nan]
# 17
# [ 4.  5. nan nan nan nan] [ 1.  2. nan nan nan nan]
# 18
# [ 4.  1.  6.  5. nan nan] [ 4.  1.  5.  2. nan nan nan]
# 19
# [ 1.  5.  3.  2. nan nan] [ 5.  4.  2.  1. nan nan]
# 20
# [ 6.  3.  2.  1.  4. nan] [ 1.  2.  0.  4.  5. nan nan]
# 21
# [ 1.  4. nan nan nan nan] [ 4.  5. nan nan nan nan]
# 22
# [ 6.  1.  4.  2. nan nan] [ 2.  5.  4.  1. nan nan nan]
# 23
# [ 1.  5.  2.  3.  4. nan] [ 4.  0.  2.  5.  3. nan]
# 24
# [ 0.  2.  4. nan nan nan] [ 1.  5.  2. nan nan nan]
# 25
# [ 3.  0.  1. nan nan nan] [ 5.  1.  2. nan nan nan]
# 26
# [ 0.  3.  4. nan nan nan] [ 4.  1.  2. nan nan nan]
# 27
# [ 0.  2.  4.  3. nan nan] [ 2.  4.  1.  5. nan nan]
# 28
# [ 3.  0.  1.  2. nan nan] [ 2.  4.  5.  1. nan nan]
# 29
# [ 4.  1.  2. nan nan nan] [ 2.  5.  1. nan nan nan nan]
# 30
# [ 2.  1.  6. nan nan nan] [ 0.  2.  5. nan nan nan nan]
# 31
# [ 4.  6.  3. nan nan nan] [ 1.  2.  5. nan nan nan nan]
# 32
# [ 3.  1.  4. nan nan nan] [ 1.  5.  2. nan nan nan]
# 33
# [ 1.  2.  5. nan nan nan] [ 4.  1.  5. nan nan nan]
# 34
# [ 5.  1.  3.  2. nan nan] [ 4.  5.  1.  2. nan nan]
# 35
# [ 0.  5.  2. nan nan nan] [ 2.  4.  5. nan nan nan]
# 36
# [ 2.  1. nan nan nan nan] [ 5.  2. nan nan nan nan]
# 37
# [ 2.  0.  3.  1.  4. nan] [ 5.  1.  4.  2.  0. nan]
# 38
# [ 0.  6.  5.  3. nan nan] [ 1.  4.  0.  5. nan nan nan]
# 39
# [ 2.  5. nan nan nan nan] [ 1.  5. nan nan nan nan]
# 40
# [ 1. nan nan nan nan nan] [ 4. nan nan nan nan nan nan]
# 41
# [ 0.  4.  1.  2. nan nan] [ 1.  4.  5.  2. nan nan]
# 42
# [ 3.  0.  4. nan nan nan] [ 1.  5.  2. nan nan nan]
# 43
# [ 4.  2.  1. nan nan nan] [ 1.  2.  5. nan nan nan]
# 44
# [ 2.  3.  4.  0. nan nan] [ 5.  4.  2.  1. nan nan nan]
# 45
# [ 2.  3.  4.  1.  5. nan] [ 3.  1.  4.  2.  5. nan]
# 46
# [ 2.  3. nan nan nan nan] [ 1.  2. nan nan nan nan]
# 47
# [ 0.  3. nan nan nan nan] [ 2.  4. nan nan nan nan]
# 48
# [ 1.  3.  4. nan nan nan] [ 1.  4.  3. nan nan nan]
# 49
# [ 2.  6.  5. nan nan nan] [ 4.  5.  1. nan nan nan nan]
# 50
# [ 3.  0.  5.  1. nan nan] [ 5.  4.  1.  2. nan nan nan]
# 51
# [ 4.  3. nan nan nan nan] [ 2.  4. nan nan nan nan nan]
# 52
# [ 3.  4. nan nan nan nan] [ 4.  1. nan nan nan nan]
# 53
# [ 2.  0.  1. nan nan nan] [ 2.  5.  1. nan nan nan]
# 54
# [ 0.  4.  1.  3. nan nan] [ 1.  2.  5.  0. nan nan]
# 55
# [ 4.  1.  5.  0. nan nan] [ 2.  5.  1.  4. nan nan]
# 56
# [ 1.  4.  3. nan nan nan] [ 4.  1.  5. nan nan nan]
# 57
# [ 0.  4. nan nan nan nan] [ 2.  4. nan nan nan nan]
# 58
# [ 5.  2.  3.  4.  1. nan] [ 4.  3.  0.  5.  1. nan]
# 59
# [ 0.  6.  5.  3. nan nan] [ 5.  1.  4.  2. nan nan nan]
# 60
# [ 1.  3. nan nan nan nan] [ 1.  4. nan nan nan nan nan]
# 61
# [ 0.  2.  4. nan nan nan] [ 0.  4.  5. nan nan nan]
# 62
# [ 4.  3.  1. nan nan nan] [ 4.  5.  2. nan nan nan]
# 63
# [ 4.  2.  3.  1. nan nan] [ 5.  4.  1.  2. nan nan]
# 64
# [ 2.  0.  4. nan nan nan] [ 5.  2.  1. nan nan nan nan]
# 65
# [ 2.  4. nan nan nan nan] [ 4.  0. nan nan nan nan]
# 66
# [ 0.  2.  5.  3. nan nan] [ 5.  2.  4.  1. nan nan]
# 67
# [ 4.  5.  3. nan nan nan] [ 5.  4.  2. nan nan nan]
# 68
# [ 4.  2.  1.  3. nan nan] [ 2.  5.  1.  4. nan nan]
# 69
# [ 4.  1.  3. nan nan nan] [ 5.  4.  1. nan nan nan]
# 70
# [ 4.  3.  2.  1. nan nan] [ 2.  5.  4.  1. nan nan]
# 71
# [ 0.  3.  5. nan nan nan] [ 2.  0.  5. nan nan nan]
# 72
# [ 5.  2.  4.  1. nan nan] [ 5.  2.  1.  4. nan nan nan]
# 73
# [ 3.  0. nan nan nan nan] [ 5.  1. nan nan nan nan]
# 74
# [ 1.  4.  0.  2. nan nan] [ 4.  5.  1.  2. nan nan]
# 75
# [ 0.  4.  1.  5. nan nan] [ 5.  4.  2.  1. nan nan]
# 76
# [ 3.  4.  1. nan nan nan] [ 1.  2.  4. nan nan nan nan]
# 77
# [ 3.  4.  1. nan nan nan] [ 2.  5.  1. nan nan nan]
# 78
# [ 2.  0.  1. nan nan nan] [ 4.  1.  5. nan nan nan]
# 79
# [ 3.  2.  0.  5. nan nan] [ 5.  2.  4.  1. nan nan nan nan]
# 80
# [ 2.  3.  4.  0. nan nan] [ 1.  4.  5.  2. nan nan]
# 81
# [ 2.  5.  3. nan nan nan] [ 5.  1.  2. nan nan nan]
# 82
# [ 1.  0.  3.  4. nan nan] [ 5.  1.  4.  2. nan nan]
# 83
# [ 1.  0.  2.  5. nan nan] [ 0.  1.  4.  5. nan nan]
# 84
# [ 0.  2.  1.  5. nan nan] [ 5.  2.  1.  4. nan nan]
# 85
# [ 3.  4.  5. nan nan nan] [ 1.  2.  5. nan nan nan nan]
# 86
# [ 4.  6.  5.  1. nan nan] [ 1.  2.  5.  4. nan nan nan]
# 87
# [ 2.  0.  3.  4.  5. nan] [ 4.  2.  1.  5.  0. nan nan nan]
# 88
# [ 1.  6.  2.  5. nan nan] [ 5.  1.  4.  2. nan nan nan]
# 89
# [ 0.  2. nan nan nan nan] [ 1.  4. nan nan nan nan]
# 90
# [ 1.  5.  3.  6. nan nan] [ 2.  1.  5.  4. nan nan nan]
# 91
# [ 0.  1.  4.  7. nan nan] [ 1.  3.  5.  2. nan nan nan nan nan]
# 92
# [ 2.  4. nan nan nan nan] [ 1.  2. nan nan nan nan]
# 93
# [ 4.  2.  1.  0.  3. nan] [ 2.  4.  0.  5.  1. nan]
# 94
# [ 3.  2.  1.  4. nan nan] [ 5.  1.  2.  4. nan nan]
# 95
# [ 0.  4.  3. nan nan nan] [ 5.  4.  1. nan nan nan]
# 96
# [ 4.  2. nan nan nan nan] [ 1.  4. nan nan nan nan]
# 97
# [ 0.  4.  1.  2. nan nan] [ 1.  2.  4.  5. nan nan nan nan]
# 98
# [ 4.  0.  5. nan nan nan] [ 4.  5.  2. nan nan nan]
# 99
# [ 2.  0.  4. nan nan nan] [ 5.  2.  4. nan nan nan]
# 100
# [ 1.  4.  2. nan nan nan] [ 1.  2.  5. nan nan nan]
# 101
# [ 2.  0.  3. nan nan nan] [ 2.  5.  4. nan nan nan]
# 102
# [ 2.  1.  4.  3. nan nan] [ 2.  1.  5.  4. nan nan]
# 103
# [ 0.  5.  3.  1. nan nan] [ 5.  1.  4.  2. nan nan]
# 104
# [ 0.  1.  2.  4. nan nan] [ 2.  4.  5.  1. nan nan]
# 105
# [ 2.  1.  3. nan nan nan] [ 5.  0.  2. nan nan nan]
# 106
# [ 4.  0.  6. nan nan nan] [ 2.  5.  1. nan nan nan nan nan nan]
# 107
# [ 3.  1.  5. nan nan nan] [ 4.  2.  1. nan nan nan]
# 108
# [ 2.  0.  3. nan nan nan] [ 4.  2.  1. nan nan nan]
# 109
# [ 0.  4.  7.  2. nan nan] [ 2.  5.  1.  4. nan nan nan nan nan]
# 110
# [ 0.  3.  2.  4. nan nan] [ 5.  2.  1.  4. nan nan]
# 111
# [ 2.  3.  1. nan nan nan] [ 2.  1.  4. nan nan nan]
# 112
# [ 3.  2.  1.  5. nan nan] [ 2.  5.  4.  1. nan nan]
# 113
# [ 2.  1.  4. nan nan nan] [ 4.  2.  0. nan nan nan]
# 114
# [ 3.  0.  4. nan nan nan] [ 4.  2.  5. nan nan nan]
# 115
# [ 3.  0.  5. nan nan nan] [ 5.  2.  0. nan nan nan]
# 116
# [ 0.  3.  6. nan nan nan] [ 4.  5.  1. nan nan nan nan]
# 117
# [ 2.  4.  0.  1. nan nan] [ 1.  4.  5.  2. nan nan]
# 118
# [ 6.  0.  4.  1. nan nan] [ 5.  4.  2.  1. nan nan nan]
# 119
# [ 3.  0.  6.  2. nan nan] [ 1.  2.  3.  4. nan nan nan]
# 120
# [ 3.  2.  5.  4. nan nan] [ 5.  4.  2.  1. nan nan nan nan]
# 121
# [ 4.  5.  2. nan nan nan] [ 2.  4.  1. nan nan nan]
# 122
# [ 6.  2.  1.  3. nan nan] [ 2.  5.  4.  1. nan nan nan]
# 123
# [ 2.  4.  3. nan nan nan] [ 5.  2.  1. nan nan nan nan nan nan nan]
# 124
# [ 0.  3.  2. nan nan nan] [ 5.  1.  4. nan nan nan nan nan]
# 125
# [ 4.  0.  1.  3. nan nan] [ 2.  1.  5.  4. nan nan]
# 126
# [ 0.  4.  2.  5. nan nan] [ 4.  1.  5.  2. nan nan]
# 127
# [ 2.  0.  4.  3. nan nan] [ 1.  2.  4.  5. nan nan]
# 128
# [ 4.  1.  2.  3. nan nan] [ 4.  1.  3.  5. nan nan nan]
# 129
# [ 3.  0.  5.  4. nan nan] [ 5.  2.  4.  1. nan nan nan]
# 130
# [ 2.  1.  4.  0. nan nan] [ 5.  4.  2.  1. nan nan]
# 131
# [ 1.  3.  0. nan nan nan] [ 1.  4.  5. nan nan nan nan]
# 132
# [ 4.  2.  1. nan nan nan] [ 5.  1.  2. nan nan nan]
# 133
# [ 1.  2.  3.  0. nan nan] [ 1.  5.  4.  2. nan nan]
# 134
# [ 3.  0.  2.  4. nan nan] [ 1.  2.  3.  5. nan nan]
# 135
# [ 1.  3.  0. nan nan nan] [ 5.  4.  2. nan nan nan]
# 136
# [ 1.  5.  6. nan nan nan] [ 2.  1.  5. nan nan nan nan nan nan nan]
# 137
# [ 0.  3.  1. nan nan nan] [ 5.  0.  1. nan nan nan]
# 138
# [ 1.  5.  2.  3.  4. nan] [ 4.  1.  2.  5.  0. nan]
# 139
# [ 3.  0.  2. nan nan nan] [ 5.  4.  2. nan nan nan]
# 140
# [ 1.  0.  5.  2. nan nan] [ 4.  5.  1.  2. nan nan]
# 141
# [ 1.  3. nan nan nan nan] [ 5.  3. nan nan nan nan]
# 142
# [ 1.  5.  0.  2. nan nan] [ 4.  5.  1.  2. nan nan]
# 143
# [ 1.  3. nan nan nan nan] [ 1.  4. nan nan nan nan]
# 144
# [ 1.  5.  4.  3. nan nan] [ 5.  2.  1.  4. nan nan]
# 145
# [ 2.  4. nan nan nan nan] [ 5.  2. nan nan nan nan]
# 146
# [ 0.  1. nan nan nan nan] [ 0.  4. nan nan nan nan]
# 147
# [ 4.  6.  0.  5. nan nan] [ 4.  2.  5.  1. nan nan nan]
# 148
# [ 5.  0.  3.  2. nan nan] [ 2.  5.  1.  4. nan nan]
# 149
# [ 2.  5. nan nan nan nan] [ 1.  4. nan nan nan nan]
# 150
# [ 4.  5.  6.  2. nan nan] [ 5.  1.  4.  0. nan nan nan]
# 151
# [ 1.  3. nan nan nan nan] [ 1.  5. nan nan nan nan]
# 152
# [ 2.  4. nan nan nan nan] [ 1.  4. nan nan nan nan nan]
# 153
# [ 3.  2.  0. nan nan nan] [ 5.  1.  0. nan nan nan]
# 154
# [ 2.  5.  1. nan nan nan] [ 1.  4.  5. nan nan nan]
# 155
# [ 1.  3.  4.  2. nan nan] [ 1.  5.  4.  2. nan nan]
# 156
# [ 1.  0.  7. nan nan nan] [ 5.  2.  1. nan nan nan nan nan]
# 157
# [ 2.  5. nan nan nan nan] [ 1.  4. nan nan nan nan]
# 158
# [ 3.  4.  1. nan nan nan] [ 5.  3.  2. nan nan nan nan]
# 159
# [ 0.  1.  3.  2. nan nan] [ 4.  1.  5.  2. nan nan]
# 160
# [ 1.  4.  3.  0. nan nan] [ 4.  2.  1.  5. nan nan]
# 161
# [ 0.  1.  3. nan nan nan] [ 1.  4.  5. nan nan nan nan]
# 162
# [ 6.  1.  3. nan nan nan] [ 1.  2.  0. nan nan nan nan]
# 163
# [ 2.  4. nan nan nan nan] [ 4.  1. nan nan nan nan]
# 164
# [ 1.  2.  4. nan nan nan] [ 1.  5.  2. nan nan nan]
# 165
# [ 2.  1.  3. nan nan nan] [ 2.  5.  0. nan nan nan]
# 166
# [ 3.  2.  6.  1. nan nan] [ 0.  5.  1.  2. nan nan nan nan]
# 167
# [ 3.  1.  0.  4. nan nan] [ 4.  5.  2.  1. nan nan]
# 168
# [ 2.  3.  1. nan nan nan] [ 2.  3.  4. nan nan nan]
# 169
# [ 1.  3.  5.  0. nan nan] [ 4.  5.  2.  1. nan nan]
# 170
# [ 1.  2.  3.  0. nan nan] [ 4.  1.  5.  2. nan nan]
# 171
# [ 1.  8.  3.  4. nan nan] [ 0.  5.  1.  3. nan nan nan nan nan]
# 172
# [ 2.  0.  4. nan nan nan] [ 1.  5.  3. nan nan nan]
# 173
# [ 1.  2.  3. nan nan nan] [ 5.  1.  4. nan nan nan nan]
# 174
# [ 1.  4.  2. nan nan nan] [ 4.  5.  1. nan nan nan]
# 175
# [ 4.  0.  3.  2. nan nan] [ 5.  1.  2.  4. nan nan]
# 176
# [ 4.  0.  5.  2. nan nan] [ 2.  5.  0.  1. nan nan]
# 177
# [ 7.  5.  4.  1. nan nan] [ 2.  4.  5.  1. nan nan nan nan]
# 178
# [ 0.  4.  5. nan nan nan] [ 5.  2.  4. nan nan nan nan]
# 179
# [ 1.  2.  5.  0. nan nan] [ 5.  4.  1.  2. nan nan]
# 180
# [ 1.  2.  5. nan nan nan] [ 3.  2.  1. nan nan nan]
# 181
# [ 3.  2.  4.  1. nan nan] [ 4.  5.  1.  0. nan nan]
# 182
# [ 5.  2. nan nan nan nan] [ 1.  4. nan nan nan nan]
# 183
# [ 1.  3.  0.  2. nan nan] [ 5.  2.  4.  1. nan nan]
# 184
# [ 1.  3.  2.  6. nan nan] [ 1.  2.  5.  3. nan nan nan]
# 185
# [ 4. nan nan nan nan nan] [ 2. nan nan nan nan nan]
# 186
# [ 3.  2.  4.  1.  5. nan] [ 5.  3.  2.  4.  1. nan]
# 187
# [ 1.  3.  2.  5. nan nan] [ 2.  4.  5.  1. nan nan]
# 188
# [ 0.  6.  5.  3. nan nan] [ 0.  4.  1.  2. nan nan nan nan nan]
# 189
# [ 4.  0.  1.  7. nan nan] [ 1.  2.  4.  5. nan nan nan nan nan]
# 190
# [ 2.  0.  5.  4. nan nan] [ 2.  1.  4.  5. nan nan]
# 191
# [ 0.  4.  3.  5. nan nan] [ 5.  1.  2.  4. nan nan]
# 192
# [ 1.  0.  2. nan nan nan] [ 1.  2.  5. nan nan nan nan nan nan]
# 193
# [ 0. nan nan nan nan nan] [ 4. nan nan nan nan nan]
# 194
# [ 0.  2.  3. nan nan nan] [ 1.  5.  4. nan nan nan nan]
# 195
# [ 1.  5.  4.  2. nan nan] [ 1.  4.  5.  2. nan nan]
# 196
# [ 2.  0. nan nan nan nan] [ 2.  5. nan nan nan nan]
# 197
# [ 0.  4.  3.  1. nan nan] [ 4.  1.  2.  5. nan nan]
# 198
# [ 1.  3.  0. nan nan nan] [ 5.  1.  3. nan nan nan]
# 199
# [ 2.  3.  0.  1.  4. nan] [ 0.  2.  1.  4.  5. nan nan nan]
# 200
# [ 3.  5.  7. nan nan nan] [ 5.  4.  2. nan nan nan nan nan]
# 201
# [ 3.  6.  1. nan nan nan] [ 5.  1.  2. nan nan nan nan]
# 202
# [ 3.  2.  1. nan nan nan] [ 2.  5.  4. nan nan nan]
# 203
# [ 0.  4.  6. nan nan nan] [ 1.  2.  4. nan nan nan nan nan nan]
# 204
# [ 3.  1.  4.  5. nan nan] [ 1.  3.  4.  2. nan nan]
# 205
# [ 5.  0.  2.  6. nan nan] [ 3.  5.  2.  4. nan nan nan]
# 206
# [ 2.  0.  1. nan nan nan] [ 4.  1.  5. nan nan nan nan]
# 207
# [ 4.  2. nan nan nan nan] [ 2.  1. nan nan nan nan]
# 208
# [ 4.  1.  0.  2. nan nan] [ 4.  5.  2.  1. nan nan]
# 209
# [ 1.  0.  2. nan nan nan] [ 1.  2.  5. nan nan nan nan]
# 210
# [ 3.  5.  1.  2. nan nan] [ 2.  4.  1.  5. nan nan nan]
# 211
# [3. 4. 1. 2. 5. 7.] [ 2.  5.  4.  1.  3.  0. nan nan]
# 212
# [ 0.  3.  2.  4.  6. nan] [ 3.  2.  4.  5.  1. nan nan]
# 213
# [ 4.  2.  0.  1. nan nan] [ 4.  5.  2.  3. nan nan]
# 214
# [ 2.  3.  4.  5. nan nan] [ 4.  2.  1.  5. nan nan]
# 215
# [ 0.  2.  4.  1. nan nan] [ 5.  4.  2.  1. nan nan nan]
# 216
# [ 4.  2.  1. nan nan nan] [ 4.  5.  1. nan nan nan]
# 217
# [ 1.  3.  0.  2. nan nan][ 5.  1.  2.  4. nan nan]
# 218
# [ 1.  3.  4. nan nan nan] [ 5.  4.  2. nan nan nan]
# 219
# [ 4.  5. nan nan nan nan] [ 2.  3. nan nan nan nan]
# 220
# [ 2.  3.  5. nan nan nan] [ 2.  5.  4. nan nan nan]
# 221
# [ 4.  5.  1.  2. nan nan] [ 2.  4.  1.  5. nan nan]
# 222
# [ 1.  7.  4.  6. nan nan] [ 5.  2.  4.  1. nan nan nan nan]
# 223
# [ 1.  2.  5.  0. nan nan] [ 1.  3.  2.  5. nan nan]
# 224
# [ 2.  0.  5. nan nan nan] [ 5.  2.  0. nan nan nan nan nan nan]
# 225
# [ 1.  0.  4.  3. nan nan] [ 2.  5.  4.  1. nan nan]
# 226
# [ 5.  4.  1.  0. nan nan] [ 1.  4.  2.  5. nan nan]
# 227
# [ 1.  3.  2.  0. nan nan] [ 4.  1.  2.  5. nan nan]
# 228
# [ 1.  0.  3. nan nan nan] [ 3.  5.  2. nan nan nan]
# 229
# [ 1.  3.  6. nan nan nan] [ 2.  5.  1. nan nan nan nan]
# 230
# [ 2.  3.  1. nan nan nan] [ 5.  2.  1. nan nan nan]
# 231
# [ 3.  9.  2.  8. nan nan] [ 0.  2.  1.  4. nan nan nan nan nan nan]
# 232
# [ 4.  2.  1. nan nan nan] [ 1.  2.  5. nan nan nan]
# 233
# [ 1.  0.  4. nan nan nan] [ 5.  1.  2. nan nan nan]
# 234
# [ 0.  4.  3. nan nan nan] [ 5.  4.  2. nan nan nan]
# 235
# [ 4.  0.  5.  2. nan nan] [ 5.  3.  4.  1. nan nan nan]
# 236
# [ 3.  2.  1.  0. nan nan] [ 1.  5.  2.  4. nan nan]
# 237
# [ 1.  3.  4.  2.  6. nan] [ 1.  4.  5.  2.  3. nan nan]
# 238
# [ 0.  5. nan nan nan nan] [ 1.  5. nan nan nan nan]
# 239
# [ 1.  4.  5. nan nan nan] [ 1.  5.  4. nan nan nan]
# 240
# [ 0.  4.  3. nan nan nan] [ 1.  2.  5. nan nan nan]
# 241
# [ 2.  1. nan nan nan nan] [ 5.  2. nan nan nan nan]
# 242
# [ 1.  2.  5.  3. nan nan] [ 2.  5.  4.  1. nan nan]
# 243
# [ 1.  0.  3.  4. nan nan] [ 1.  2.  4.  5. nan nan]
# 244
# [ 1.  3.  2.  4. nan nan] [ 0.  1.  5.  4. nan nan]
# 245
# [ 4.  3.  1. nan nan nan] [ 1.  4.  5. nan nan nan]
# 246
# [ 4.  2.  0.  3. nan nan] [ 2.  5.  4.  1. nan nan]
# 247
# [ 0.  3.  5. nan nan nan] [ 1.  2.  5. nan nan nan]
# 248
# [ 2.  4.  3.  5. nan nan] [ 5.  4.  1.  2. nan nan]
# 249
# [ 4.  7. nan nan nan nan] [ 2.  4. nan nan nan nan nan nan]
# 250
# [ 4.  1.  3. nan nan nan] [ 1.  2.  5. nan nan nan]
# 251
# [ 5.  1. nan nan nan nan] [ 4.  2. nan nan nan nan]
# 252
# [ 1.  3.  2.  5. nan nan] [ 5.  3.  2.  4. nan nan]
# 253
# [ 1.  2.  3.  7. nan nan] [ 2.  1.  5.  4. nan nan nan nan nan]
# 254
# [ 0.  3.  4. nan nan nan] [ 2.  5.  4. nan nan nan nan nan]
# 255
# [ 0.  6. nan nan nan nan] [ 5.  3. nan nan nan nan nan nan nan]
# 256
# [ 0.  2.  1.  3. nan nan] [ 1.  2.  5.  4. nan nan]
# 257
# [ 0.  3.  1.  5.  2. nan] [ 2.  1.  0.  4.  3. nan]
# 258
# [ 3.  6. nan nan nan nan] [ 2.  4. nan nan nan nan nan]
# 259
# [ 0.  2.  5. nan nan nan] [ 2.  5.  4. nan nan nan]
# 260
# [ 2.  1.  4. nan nan nan] [ 0.  4.  1. nan nan nan]
# 261
# [ 1.  4.  5.  0. nan nan] [ 2.  4.  0.  5. nan nan]
# 262
# [ 4.  2.  0.  3. nan nan] [ 4.  3.  1.  2. nan nan]
# 263
# [ 0.  4.  2. nan nan nan] [ 5.  2.  4. nan nan nan]
# 264
# [ 0.  6.  5. nan nan nan] [ 4.  2.  3. nan nan nan nan]
# 265
# [ 1.  3.  0.  5. nan nan] [ 5.  2.  0.  1. nan nan]
# 266
# [ 3.  0.  2.  4. nan nan] [ 1.  0.  2.  4. nan nan]
# 267
# [ 0.  5.  4. nan nan nan] [ 2.  4.  1. nan nan nan]
# 268
# [ 0.  3.  5. nan nan nan] [ 2.  1.  5. nan nan nan]
# 269
# [ 1.  0.  4. nan nan nan] [ 4.  1.  5. nan nan nan]
# 270
# [ 4.  3.  1. nan nan nan] [ 2.  5.  4. nan nan nan]
# 271
# [ 2.  0.  4. nan nan nan] [ 5.  4.  2. nan nan nan]
# 272
# [ 2.  3.  4. nan nan nan] [ 5.  3.  1. nan nan nan nan]
# 273
# [ 1.  0.  2. nan nan nan] [ 4.  5.  1. nan nan nan]
# 274
# [ 2.  1.  4. nan nan nan] [ 5.  1.  2. nan nan nan]
# 275
# [ 2.  1.  0. nan nan nan] [ 4.  5.  1. nan nan nan]
# 276
# [ 2.  5.  1.  0. nan nan] [ 1.  4.  3.  5. nan nan]
# 277
# [ 6.  3.  2.  1. nan nan] [ 1.  5.  4.  2. nan nan nan]
# 278
# [ 1.  5. nan nan nan nan] [ 2.  1. nan nan nan nan nan]
# 279
# [ 6.  3.  0. nan nan nan] [ 1.  4.  0. nan nan nan nan nan]
# 280
# [ 1. nan nan nan nan nan] [ 0. nan nan nan nan nan]
# 281
# [ 1.  3.  4.  2. nan nan] [ 1.  2.  4.  5. nan nan]
# 282
# [ 2.  0.  1.  3. nan nan] [ 4.  5.  1.  0. nan nan]
# 283
# [ 5.  4.  1.  0. nan nan] [ 4.  2.  1.  0. nan nan nan nan]
# 284
# [ 1.  2.  4.  6. nan nan] [ 5.  0.  4.  3. nan nan nan]
# 285
# [ 2.  1.  4.  0.  3. nan] [ 1.  4.  5.  3.  2. nan nan]

# %%
matching_parton[8]
# Out:
# array([ 3.,  1.,  2., nan, nan, nan])

# %%
matching_jet[8]
# Out:
# array([ 2.,  4.,  1., nan, nan, nan])

# %%
array = np.reshape(dR_between_parton_jet[8], [6, len(jet_pt[8])])
print(array[3,1])
dataset = pd.DataFrame({'0': array[0,:], 
                                '1': array[1,:],
                                '2': array[2,:],
                                '3': array[3,:],
                                '4': array[4,:],
                                '5': array[5,:],
                                })
print(dataset)
min_idx, min_col = dataset.stack().idxmin()
print(min_idx, min_col)
print(dataset.iloc[4, 5])
# Out:
# 2.1930006476799937
#           0         1         2         3         4         5
# 0  3.149581  0.603550  1.701497  0.931103  1.584544  2.923640
# 1  1.752561  2.123706  3.150187  2.193001  0.046727  1.905609
# 2  2.465137  0.158637  1.221188  0.686300  2.299217  2.202966
# 3  1.977741  1.379020  0.015046  1.884237  3.183373  1.861102
# 4  1.794689  3.680289  2.729886  4.081565  2.471614  2.103569
# 5  2.712163  3.581885  4.225174  3.316750  2.047230  2.583816
# 3 2
# 2.1035691052727556

# %%
parton_jet_index = np.zeros([len(parton_pdgid), 6])
jet_parton_index = []
np.zeros([len(parton_pdgid), 6])
for i in range(len(parton_pdgid)):
    jet_parton_index.append(np.zeros([len(jet_pt[i])]))


for i in range(len(parton_pdgid)):
    for j in range(0,6):
        parton_jet_index[i][j] = matching_parton[i][j]
    for k in range(len(jet_pt[i])):
        jet_parton_index[i][k] = matching_jet[i][k]

# %%
jet_barcode = []
for i in range(len(parton_pdgid)):
    jet_barcode.append(np.zeros([len(jet_pt[i])]))

jet_barcode = np.array(jet_barcode)

for i in range(len(parton_pdgid)):
    for j in range(len(jet_parton_index[i])):
        if jet_parton_index[i][j] == 0:
            jet_barcode[i][j] = barcode[0]
        elif jet_parton_index[i][j] == 1: 
            jet_barcode[i][j] = barcode[1]
        elif jet_parton_index[i][j] == 2: 
            jet_barcode[i][j] = barcode[2]
        elif jet_parton_index[i][j] == 3: 
            jet_barcode[i][j] = barcode[3]
        elif jet_parton_index[i][j] == 4: 
            jet_barcode[i][j] = barcode[4]
        elif jet_parton_index[i][j] == 5: 
            jet_barcode[i][j] = barcode[5]
        else :
            jet_barcode[i][j] = 'Nan'
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """

# %%
jet_barcode[8]
# Out:
# array([40., 20., 40., nan, nan, nan])

# %%
count_jet = 0
count_match_jet = 0
for i in range(len(jet_parton_index)):
    for j in range(len(jet_parton_index[i])):
        count_jet += 1
        if jet_parton_index[i][j] <= 5:
            count_match_jet +=1
        else : pass
print(count_jet, count_match_jet)
# Out:
# 1854 957

# %%
count_top = 0
count_top_bar = 0 
count_both = 0
for i in range(len(jet_parton_index)):
    for j in range(len(jet_parton_index[i])):
        if np.sum(jet_parton_index[i] <= 2) == 3:
            #print(jet_parton_index[i])
            count_top +=1
        elif np.sum(jet_parton_index[i] > 2) == 3:
            #print(jet_parton_index[i])
            count_top_bar +=1
        elif np.sum(jet_parton_index[i] <= 5) == 6:
            count_both +=1
        else : pass
print(count_top, count_top_bar, count_both)
# Out:
# 121 91 0

# %% [markdown]
# ## Saved selected events
# ---

# %%
# lene = len(parton_pdgid)
# #Save the event which pass the selection
# with h5py.File("./event_record_pptt_10k_new.h5",'w') as f:
#     dt = h5py.vlen_dtype(np.dtype('int32'))

#     hdf5_jet_parton_index = f.create_dataset('jet_parton_index', (lene, ), dtype=dt)
#     hdf5_jet_barcode = f.create_dataset('jet_barcode', (lene, ), dtype=dt)
#     hdf5_jet_pt = f.create_dataset('jet_pt', (lene, ), dtype=dt)
#     hdf5_jet_eta = f.create_dataset('jet_eta', (lene, ), dtype=dt)
#     hdf5_jet_phi = f.create_dataset('jet_phi', (lene, ), dtype=dt)
#     hdf5_jet_mass = f.create_dataset('jet_mass', (lene, ), dtype=dt)
#     hdf5_jet_btag = f.create_dataset('jet_btag', (lene, ), dtype=dt)

#     for i in range(lene):
#         hdf5_jet_parton_index[i] = jet_parton_index[i]
#         hdf5_jet_barcode[i] = jet_barcode[i]
#         hdf5_jet_pt[i] = jet_pt[i]
#         hdf5_jet_eta[i] = jet_eta[i]
#         hdf5_jet_phi[i] = jet_phi[i]
#         hdf5_jet_mass[i] = jet_mass[i]
#         hdf5_jet_btag[i] = jet_btag[i]

#     hdf5_parton_jet_index = f.create_dataset('parton_jet_index', (lene, ), dtype=dt)
#     hdf5_parton_pdgid = f.create_dataset('parton_pdgid', (lene, ), dtype=dt)
#     hdf5_parton_barcode = f.create_dataset('parton_barcode', (lene, ), dtype=dt)
#     hdf5_parton_pt = f.create_dataset('parton_pt', (lene, ), dtype=dt)
#     hdf5_parton_eta = f.create_dataset('parton_eta', (lene, ), dtype=dt)
#     hdf5_parton_phi = f.create_dataset('parton_phi', (lene, ), dtype=dt)
#     hdf5_parton_mass = f.create_dataset('parton_mass', (lene, ), dtype=dt)

#     for i in range(lene):
#         hdf5_parton_jet_index[i] = parton_jet_index[i]
#         hdf5_parton_pdgid[i] = parton_pdgid[i]
#         hdf5_parton_barcode[i] = parton_barcode[i]
#         hdf5_parton_pt[i] = parton_pt[i]
#         hdf5_parton_eta[i] = parton_eta[i]
#         hdf5_parton_phi[i] = parton_phi[i]
#         hdf5_parton_mass[i] = parton_mass[i]
