# %% [markdown]
# ## This is a demo of `how to read the hdf5 file` and describe the data structure of our file.
# ---

# %% [markdown]
# ### Import Package
# Import `h5py` to read hdf5 in python.

# %%
import h5py 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Input data by `h5py`
# Using `h5py` package can help you to parse the hdf5 file.

# %%
f = h5py.File('../output/output.h5','r') 
g = h5py.File("../output/output_chi2.h5", 'r')

# %% [markdown]
# ### Dig into data structure
# To see how many groups defined in the hdf5 file, you can use the following script.

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['N_match_top_in_event', 'jet_barcode', 'jet_btag', 'jet_eta', 'jet_mass', 'jet_parton_index', 'jet_phi', 'jet_pt', 'parton_barcode', 'parton_eta', 'parton_jet_index', 'parton_mass', 'parton_pdgid', 'parton_phi', 'parton_pt']>

# %%
g.keys()
# Out:
# <KeysViewHDF5 ['N_match_top_in_event', 'jet_barcode', 'jet_btag', 'jet_eta', 'jet_mass', 'jet_parton_index', 'jet_phi', 'jet_pt', 'parton_barcode', 'parton_eta', 'parton_jet_index', 'parton_mass', 'parton_pdgid', 'parton_phi', 'parton_pt']>

# %% [markdown]
# The output upon shows that we have 14 groups of data, contains the properties of `jet` and `parton`.
# We can input the data by the following method.

# %%
jet_pt = f['jet_pt']
jet_phi = f['jet_phi']
jet_eta = f['jet_eta']
jet_barcode = f['jet_barcode']
jet_mass = f['jet_mass']
jet_btag = f['jet_btag']
jet_parton_index = f['jet_parton_index']

parton_pdgid = f['parton_pdgid']
parton_pt = f['parton_pt']
parton_eta = f['parton_eta']
parton_phi = f['parton_phi']
parton_mass = f['parton_mass']
parton_barcode = f['parton_barcode']
parton_jet_index = f['parton_jet_index']

N_match_top_in_event = f['N_match_top_in_event']

# %%
jet_pt_chi2 = g['jet_pt']
jet_phi_chi2 = g['jet_phi']
jet_eta_chi2 = g['jet_eta']
jet_barcode_chi2 = g['jet_barcode']
jet_mass_chi2 = g['jet_mass']
jet_btag_chi2 = g['jet_btag']
jet_parton_index_chi2 = g['jet_parton_index']

parton_pdgid_chi2 = g['parton_pdgid']
parton_pt_chi2 = g['parton_pt']
parton_eta_chi2 = g['parton_eta']
parton_phi_chi2 = g['parton_phi']
parton_mass_chi2 = g['parton_mass']
parton_barcode_chi2 = g['parton_barcode']
parton_jet_index_chi2 = g['parton_jet_index']

N_match_top_in_event_chi2 = g['N_match_top_in_event']

# %%
N_match_top_in_event[0]
# Out:
# 2.0

# %% [markdown]
# ### introduction of groups
#
# * (mass, pt, eta, phi) in `jet` and `parton` represent the kinematics properties of jet and parton.
# * `barcode` is defined to represent the relation between each parton candidate and jet.
# * `parton_jet_index` and `jet_parton_index` is to point out which jet/parton is matched to(by using min dR(parton. jet))
# * `btag` is the binary record, shows whether a jet has been tagged as `b jet` or not.

# %% [markdown]
# ### Example
# To check how many events in this hdf5 file.

# %%
len(N_match_top_in_event)
# Out:
# 2271

# %%
plt.figure(figsize=(8,6))
plt.hist(N_match_top_in_event, bins=3, histtype='step')
plt.xticks([0,1,2])
plt.ylabel('Number of events')
plt.xlabel('Distribution of matched top candidates')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(N_match_top_in_event_chi2, bins=3, histtype='step')
plt.xticks([0,1,2])
plt.ylabel('Number of events')
plt.xlabel('Distribution of matched top candidates(chi2 minimizer)')
plt.show()

# %%
W_plus_inv = []
W_minus_inv = []

tmp = 0
tmp_p = 0

for i in range(len(N_match_top_in_event)):
    if N_match_top_in_event[i] == 2:
        pt_1 = parton_pt[i][1]
        pt_2 = parton_pt[i][2]

        eta_1 = parton_eta[i][1]
        eta_2 = parton_eta[i][2]

        phi_1 = parton_phi[i][1]
        phi_2 = parton_phi[i][2]

        tmp = np.sqrt( 2*parton_pt[i][1]*parton_pt[i][2]*( np.cosh( parton_eta[i][1] - parton_eta[i][2] ) - np.cos( parton_phi[i][1] - parton_phi[i][2] ) ) )

        pt_3 = parton_pt[i][4]
        pt_4 = parton_pt[i][5]

        eta_3 = parton_eta[i][4]
        eta_4 = parton_eta[i][5]

        phi_3 = parton_phi[i][4]
        phi_4 = parton_phi[i][5]

        tmp_p = np.sqrt( 2*pt_3*pt_4*( np.cosh( eta_3 - eta_4 ) - np.cos( phi_3 - phi_4 ) ) )

        W_plus_inv.append(tmp)
        W_minus_inv.append(tmp_p)

# %%
W_plus_inv_chi2 = []
W_minus_inv_chi2 = []

tmp = 0
tmp_p = 0

for i in range(len(N_match_top_in_event_chi2)):
    if N_match_top_in_event_chi2[i] == 2:
        pt_1 = parton_pt_chi2[i][1]
        pt_2 = parton_pt_chi2[i][2]

        eta_1 = parton_eta_chi2[i][1]
        eta_2 = parton_eta_chi2[i][2]

        phi_1 = parton_phi_chi2[i][1]
        phi_2 = parton_phi_chi2[i][2]

        tmp = np.sqrt( 2*parton_pt_chi2[i][1]*parton_pt_chi2[i][2]*( np.cosh( parton_eta_chi2[i][1] - parton_eta_chi2[i][2] ) - np.cos( parton_phi_chi2[i][1] - parton_phi_chi2[i][2] ) ) )

        pt_3 = parton_pt_chi2[i][4]
        pt_4 = parton_pt_chi2[i][5]

        eta_3 = parton_eta_chi2[i][4]
        eta_4 = parton_eta_chi2[i][5]

        phi_3 = parton_phi_chi2[i][4]
        phi_4 = parton_phi_chi2[i][5]

        tmp_p = np.sqrt( 2*pt_3*pt_4*( np.cosh( eta_3 - eta_4 ) - np.cos( phi_3 - phi_4 ) ) )

        W_plus_inv_chi2.append(tmp)
        W_minus_inv_chi2.append(tmp_p)

# %%
def plot_hist_W(target, x_label, img_name):
    plt.figure(figsize=(8,6))
    height, width = np.histogram(target, bins=100, range=(0,200) )
    maxi =  height.max()
    idxx = np.where( height == maxi ) 
    legend = idxx[0].max()
    plt.hist(target, bins = 100 ,histtype='step', range=(0,200), label='Mass peak: {0:.2f} GeV'.format( width[legend] ))
    plt.xlabel(x_label)
    plt.ylabel(r'$\frac{dN}{dm}$')
    plt.legend(loc='upper right')
    plt.savefig(img_name)
    plt.show()

def plot_hist_W_compare(target_1, x_label, target_2, img_name):
    plt.figure(figsize=(8,6))
    height_1, width_1 = np.histogram(target_1, bins=100, range=(0,200) )
    maxi_1 =  height_1.max()
    idxx_1 = np.where( height_1 == maxi_1 ) 
    legend_1 = idxx_1[0].max()
    plt.hist(target_1, bins = 100 ,histtype='step', range=(0,200), label='Mass peak: {0:.2f} GeV'.format( width_1[legend_1] ))

    height_2, width_2 = np.histogram(target_2, bins=100, range=(0,200) )
    maxi_2 =  height_2.max()
    idxx_2 = np.where( height_2 == maxi_2 ) 
    legend_2 = idxx_2[0].max()
    plt.hist(target_2, bins = 100 ,histtype='step', range=(0,200), label='Mass peak: {0:.2f} GeV(chi2)'.format( width_2[legend_2] ))

    plt.xlabel(x_label)
    plt.ylabel(r'$\frac{dN}{dm}$')
    plt.legend(loc='upper right')
    plt.savefig(img_name)
    plt.show()

def plot_hist_top(target, x_label, img_name):
    plt.figure(figsize=(8,6))
    height, width = np.histogram(target, bins=100, range=(0,300) )
    maxi =  height.max()
    idxx = np.where( height == maxi ) 
    legend = idxx[0].max()
    plt.hist(target, bins = 100 ,histtype='step', range=(0,300), label='Mass peak: {0:.2f} GeV'.format( width[legend] ))
    plt.xlabel(x_label)
    plt.ylabel(r'$\frac{dN}{dm}$')
    plt.legend(loc='upper right')
    plt.savefig(img_name)
    plt.show()

def plot_hist_top_compare(target_1, x_label, target_2, img_name):
    plt.figure(figsize=(8,6))
    height_1, width_1 = np.histogram(target_1, bins=100, range=(0,300) )
    maxi_1 =  height_1.max()
    idxx_1 = np.where( height_1 == maxi_1 ) 
    legend_1 = idxx_1[0].max()
    plt.hist(target_1, bins = 100 ,histtype='step', range=(0,300), label='Mass peak: {0:.2f} GeV'.format( width_1[legend_1] ))

    height_2, width_2 = np.histogram(target_2, bins=100, range=(0,300) )
    maxi_2 =  height_2.max()
    idxx_2 = np.where( height_2 == maxi_2 ) 
    legend_2 = idxx_1[0].max()
    plt.hist(target_2, bins = 100 ,histtype='step', range=(0,300), label='Mass peak: {0:.2f} GeV(chi2)'.format( width_2[legend_2] ))

    plt.xlabel(x_label)
    plt.ylabel(r'$\frac{dN}{dm}$')
    plt.legend(loc='upper right')
    plt.savefig(img_name)
    plt.show()

# %%
plot_hist_W(W_plus_inv, r'Invariant mass of $W^{+}$', "./Pic/deltaR/inv_W_plus.png")
plot_hist_W(W_plus_inv_chi2, r'Invariant mass of $W^{+}(chi2)$', "./Pic/chi2/inv_W_plus_chi2.png")
plot_hist_W_compare(W_plus_inv, r'Invariant mass of $W^{+}$', W_plus_inv_chi2, "./Pic/compare/inv_W_plus_compare.png" )

# %%
plot_hist_W(W_minus_inv, r'Invariant mass of $W^{-}$', "./Pic/deltaR/inv_W_minus.png")
plot_hist_W(W_minus_inv_chi2, r'Invariant mass of $W^{-}(chi2)$', "./Pic/chi2/inv_W_minus_chi2.png")
plot_hist_W_compare(W_minus_inv, r'Invariant mass of $W^{-}$', W_minus_inv_chi2, "./Pic/compare/inv_W_minus_compare.png" )

# %%
top_inv = []
top_bar_inv = []
tmp = 0
tmp_p = 0

for i in range(len(N_match_top_in_event)):
    if N_match_top_in_event[i] == 2:

        pt_1 = parton_pt[i][0]
        pt_2 = parton_pt[i][1]
        pt_3 = parton_pt[i][2]

        px_1 = pt_1 * np.cos(parton_phi[i][0])
        px_2 = pt_2 * np.cos(parton_phi[i][1])
        px_3 = pt_3 * np.cos(parton_phi[i][2])

        py_1 = pt_1 * np.sin(parton_phi[i][0])
        py_2 = pt_2 * np.sin(parton_phi[i][1])
        py_3 = pt_3 * np.sin(parton_phi[i][2])

        pz_1 = pt_1 * np.sinh(parton_eta[i][0])
        pz_2 = pt_2 * np.sinh(parton_eta[i][1])
        pz_3 = pt_3 * np.sinh(parton_eta[i][2])

        e_1 = np.sqrt( (px_1**2 + py_1**2 + pz_1**2 ) + parton_mass[i][0]**2 )
        e_2 = np.sqrt( (px_2**2 + py_2**2 + pz_2**2 ) + parton_mass[i][1]**2 )
        e_3 = np.sqrt( (px_3**2 + py_3**2 + pz_3**2 ) + parton_mass[i][2]**2 )


        tmp = np.sqrt( (e_1 + e_2 + e_3)**2 - (px_1 + px_2 + px_3)**2 - (py_1 + py_2 + py_3)**2 - (pz_1 + pz_2 + pz_3)**2  )        
        top_inv.append(tmp)

# %%
top_inv_chi2 = []
top_bar_inv_chi2 = []
tmp = 0
tmp_p = 0

for i in range(len(N_match_top_in_event_chi2)):
    if N_match_top_in_event_chi2[i] == 2:

        pt_1 = parton_pt_chi2[i][0]
        pt_2 = parton_pt_chi2[i][1]
        pt_3 = parton_pt_chi2[i][2]

        px_1 = pt_1 * np.cos(parton_phi_chi2[i][0])
        px_2 = pt_2 * np.cos(parton_phi_chi2[i][1])
        px_3 = pt_3 * np.cos(parton_phi_chi2[i][2])

        py_1 = pt_1 * np.sin(parton_phi_chi2[i][0])
        py_2 = pt_2 * np.sin(parton_phi_chi2[i][1])
        py_3 = pt_3 * np.sin(parton_phi_chi2[i][2])

        pz_1 = pt_1 * np.sinh(parton_eta_chi2[i][0])
        pz_2 = pt_2 * np.sinh(parton_eta_chi2[i][1])
        pz_3 = pt_3 * np.sinh(parton_eta_chi2[i][2])

        e_1 = np.sqrt( (px_1**2 + py_1**2 + pz_1**2 ) + parton_mass_chi2[i][0]**2 )
        e_2 = np.sqrt( (px_2**2 + py_2**2 + pz_2**2 ) + parton_mass_chi2[i][1]**2 )
        e_3 = np.sqrt( (px_3**2 + py_3**2 + pz_3**2 ) + parton_mass_chi2[i][2]**2 )


        tmp = np.sqrt( (e_1 + e_2 + e_3)**2 - (px_1 + px_2 + px_3)**2 - (py_1 + py_2 + py_3)**2 - (pz_1 + pz_2 + pz_3)**2  )        
        top_inv_chi2.append(tmp)

# %%
plot_hist_top(top_inv, r'Invariant mass of $t$', "./Pic/deltaR/inv_top.png")
plot_hist_top(top_inv_chi2, r'Invariant mass of $t$(chi2)', "./Pic/chi2/inv_top_chi2.png")
plot_hist_top_compare(top_inv, r'Invariant mass of $t$', top_inv_chi2, "./Pic/compare/inv_top_compare.png")

# %%
for i in range(len(N_match_top_in_event)):
    if N_match_top_in_event[i] == 2:

        pt_3 = parton_pt[i][3]
        pt_4 = parton_pt[i][4]
        pt_5 = parton_pt[i][5]

        px_3 = pt_3 * np.cos(parton_phi[i][3])
        px_4 = pt_4 * np.cos(parton_phi[i][4])
        px_5 = pt_5 * np.cos(parton_phi[i][5])

        py_3 = pt_3 * np.sin(parton_phi[i][3])
        py_4 = pt_4 * np.sin(parton_phi[i][4])
        py_5 = pt_5 * np.sin(parton_phi[i][5])

        pz_3 = pt_3 * np.sinh(parton_eta[i][3])
        pz_4 = pt_4 * np.sinh(parton_eta[i][4])
        pz_5 = pt_5 * np.sinh(parton_eta[i][5])

        e_3 = np.sqrt( (px_3**2 + py_3**2 + pz_3**2 ) + parton_mass[i][3]**2 )
        e_4 = np.sqrt( (px_4**2 + py_4**2 + pz_4**2 ) + parton_mass[i][4]**2 )
        e_5 = np.sqrt( (px_5**2 + py_5**2 + pz_5**2 ) + parton_mass[i][5]**2 )

        tmp_p = np.sqrt( (e_3 + e_4 + e_5)**2 - (px_3 + px_4 + px_5)**2 - (py_3 + py_4 + py_5)**2 - (pz_3 + pz_4 + pz_5)**2  )
        
        top_bar_inv.append(tmp_p)

# %%
for i in range(len(N_match_top_in_event_chi2)):
    if N_match_top_in_event_chi2[i] == 2:

        pt_3 = parton_pt_chi2[i][3]
        pt_4 = parton_pt_chi2[i][4]
        pt_5 = parton_pt_chi2[i][5]

        px_3 = pt_3 * np.cos(parton_phi_chi2[i][3])
        px_4 = pt_4 * np.cos(parton_phi_chi2[i][4])
        px_5 = pt_5 * np.cos(parton_phi_chi2[i][5])

        py_3 = pt_3 * np.sin(parton_phi_chi2[i][3])
        py_4 = pt_4 * np.sin(parton_phi_chi2[i][4])
        py_5 = pt_5 * np.sin(parton_phi_chi2[i][5])

        pz_3 = pt_3 * np.sinh(parton_eta_chi2[i][3])
        pz_4 = pt_4 * np.sinh(parton_eta_chi2[i][4])
        pz_5 = pt_5 * np.sinh(parton_eta_chi2[i][5])

        e_3 = np.sqrt( (px_3**2 + py_3**2 + pz_3**2 ) + parton_mass_chi2[i][3]**2 )
        e_4 = np.sqrt( (px_4**2 + py_4**2 + pz_4**2 ) + parton_mass_chi2[i][4]**2 )
        e_5 = np.sqrt( (px_5**2 + py_5**2 + pz_5**2 ) + parton_mass_chi2[i][5]**2 )

        tmp_p = np.sqrt( (e_3 + e_4 + e_5)**2 - (px_3 + px_4 + px_5)**2 - (py_3 + py_4 + py_5)**2 - (pz_3 + pz_4 + pz_5)**2  )
        
        top_bar_inv_chi2.append(tmp_p)

# %%
plot_hist_top(top_bar_inv, r'Invariant mass of $\bar{t}$', "./Pic/deltaR/inv_top_bar.png")
plot_hist_top(top_bar_inv_chi2, r'Invariant mass of $\bar{t}$(chi2)', "./Pic/chi2/inv_top_bar_chi2.png")
plot_hist_top_compare(top_bar_inv, r'Invariant mass of $\bar{t}$', top_bar_inv_chi2, "./Pic/compare/inv_top_bar_compare.png")

# %%
W_plus_inv_jet = []
W_minus_inv_jet = []

tmp = 0
tmp_p = 0

for i in range(len(N_match_top_in_event)):
    if N_match_top_in_event[i] == 2:
        for j in range(len(jet_pt[i])):
            if jet_parton_index[i][j] == 1:
                #jet_idx = int(parton_jet_index[i][j])
                pt_1 = jet_pt[i][j]
                eta_1 = jet_eta[i][j]
                phi_1 = jet_phi[i][j]
                mass_1 = jet_mass[i][j]
                px_1 = pt_1*np.cos( phi_1 )
                py_1 = pt_1*np.sin( phi_1 )
                pz_1 = pt_1*np.sinh( eta_1 )
                e_1 = np.sqrt( (px_1**2 + py_1**2 + pz_1**2 ) + mass_1**2 ) 
                #print("W daughter 1:", j, pt_1, eta_1, phi_1, px_1, py_1, pz_1, e_1)

            if jet_parton_index[i][j] == 2:
                #jet_idx = int(parton_jet_index[i][j])
                pt_2 = jet_pt[i][j]
                eta_2 = jet_eta[i][j]
                phi_2 = jet_phi[i][j]
                mass_2 = jet_mass[i][j]
                px_2 = pt_2*np.cos( phi_2 )
                py_2 = pt_2*np.sin( phi_2 )
                pz_2 = pt_2*np.sinh( eta_2 )
                e_2 = np.sqrt( (px_2**2 + py_2**2 + pz_2**2 ) + mass_2**2 )
                #print("W daughter 2:", j, pt_2, eta_2, phi_2, px_2, py_2, pz_2, e_2)

            if jet_parton_index[i][j] == 4:
                #jet_idx = int(parton_jet_index[i][j])
                pt_4 = jet_pt[i][j]
                eta_4 = jet_eta[i][j]
                phi_4 = jet_phi[i][j]
                mass_4 = jet_mass[i][j]
                px_4 = pt_4*np.cos( phi_4 )
                py_4 = pt_4*np.sin( phi_4 )
                pz_4 = pt_4*np.sinh( eta_4 )
                e_4 = np.sqrt( (px_4**2 + py_4**2 + pz_4**2 ) + mass_4**2 )
                #print("W- daughter 1:", j, pt_4, eta_4, phi_4, px_4, py_4, pz_4, e_4)

            if jet_parton_index[i][j] == 5:
                #jet_idx = int(parton_jet_index[i][j])
                pt_5 = jet_pt[i][j]
                eta_5 = jet_eta[i][j]
                phi_5 = jet_phi[i][j]
                mass_5 = jet_mass[i][j]
                px_5 = pt_5*np.cos( phi_5 )
                py_5 = pt_5*np.sin( phi_5 )
                pz_5 = pt_5*np.sinh( eta_5 )
                e_5 = np.sqrt( (px_5**2 + py_5**2 + pz_5**2 ) + mass_5**2 )
                #print("W- daughter 2:", j, pt_5, eta_5, phi_5, px_5, py_5, pz_5, e_5)

            tmp = np.sqrt( ( e_1 + e_2 )**2 - ( px_1 + px_2 )**2 - ( py_1 + py_2 )**2 - ( pz_1 + pz_2 )**2 )
            tmp_p = np.sqrt( ( e_4 + e_5 )**2 - ( px_4 + px_5)**2 - ( py_4 + py_5 )**2 - ( pz_4 + pz_5 )**2 )

            W_plus_inv_jet.append(tmp)
            W_minus_inv_jet.append(tmp_p)

# %%
W_plus_inv_jet_chi2 = []
W_minus_inv_jet_chi2 = []

tmp = 0
tmp_p = 0

for i in range(len(N_match_top_in_event_chi2)):
    if N_match_top_in_event_chi2[i] == 2:
        for j in range(len(jet_pt_chi2[i])):
            if jet_parton_index_chi2[i][j] == 1:
                #jet_idx = int(parton_jet_index[i][j])
                pt_1 = jet_pt_chi2[i][j]
                eta_1 = jet_eta_chi2[i][j]
                phi_1 = jet_phi_chi2[i][j]
                mass_1 = jet_mass_chi2[i][j]
                px_1 = pt_1*np.cos( phi_1 )
                py_1 = pt_1*np.sin( phi_1 )
                pz_1 = pt_1*np.sinh( eta_1 )
                e_1 = np.sqrt( (px_1**2 + py_1**2 + pz_1**2 ) + mass_1**2 ) 
                #print("W daughter 1:", j, pt_1, eta_1, phi_1, px_1, py_1, pz_1, e_1)

            if jet_parton_index_chi2[i][j] == 2:
                #jet_idx = int(parton_jet_index[i][j])
                pt_2 = jet_pt_chi2[i][j]
                eta_2 = jet_eta_chi2[i][j]
                phi_2 = jet_phi_chi2[i][j]
                mass_2 = jet_mass_chi2[i][j]
                px_2 = pt_2*np.cos( phi_2 )
                py_2 = pt_2*np.sin( phi_2 )
                pz_2 = pt_2*np.sinh( eta_2 )
                e_2 = np.sqrt( (px_2**2 + py_2**2 + pz_2**2 ) + mass_2**2 )
                #print("W daughter 2:", j, pt_2, eta_2, phi_2, px_2, py_2, pz_2, e_2)

            if jet_parton_index_chi2[i][j] == 4:
                #jet_idx = int(parton_jet_index[i][j])
                pt_4 = jet_pt_chi2[i][j]
                eta_4 = jet_eta_chi2[i][j]
                phi_4 = jet_phi_chi2[i][j]
                mass_4 = jet_mass_chi2[i][j]
                px_4 = pt_4*np.cos( phi_4 )
                py_4 = pt_4*np.sin( phi_4 )
                pz_4 = pt_4*np.sinh( eta_4 )
                e_4 = np.sqrt( (px_4**2 + py_4**2 + pz_4**2 ) + mass_4**2 )
                #print("W- daughter 1:", j, pt_4, eta_4, phi_4, px_4, py_4, pz_4, e_4)

            if jet_parton_index_chi2[i][j] == 5:
                #jet_idx = int(parton_jet_index[i][j])
                pt_5 = jet_pt_chi2[i][j]
                eta_5 = jet_eta_chi2[i][j]
                phi_5 = jet_phi_chi2[i][j]
                mass_5 = jet_mass_chi2[i][j]
                px_5 = pt_5*np.cos( phi_5 )
                py_5 = pt_5*np.sin( phi_5 )
                pz_5 = pt_5*np.sinh( eta_5 )
                e_5 = np.sqrt( (px_5**2 + py_5**2 + pz_5**2 ) + mass_5**2 )
                #print("W- daughter 2:", j, pt_5, eta_5, phi_5, px_5, py_5, pz_5, e_5)

            tmp = np.sqrt( ( e_1 + e_2 )**2 - ( px_1 + px_2 )**2 - ( py_1 + py_2 )**2 - ( pz_1 + pz_2 )**2 )
            tmp_p = np.sqrt( ( e_4 + e_5 )**2 - ( px_4 + px_5)**2 - ( py_4 + py_5 )**2 - ( pz_4 + pz_5 )**2 )

            W_plus_inv_jet_chi2.append(tmp)
            W_minus_inv_jet_chi2.append(tmp_p)

# %%
plot_hist_W(W_plus_inv_jet, r'Invariant mass of $W^{+}$ (re-construct by jet)', "./Pic/deltaR/inv_W_plus_jet.png")
plot_hist_W(W_plus_inv_jet_chi2, r'Invariant mass of $W^{+}$ (re-construct by jet, chi2)', "./Pic/chi2/inv_W_plus_jet_chi2.png")
plot_hist_W_compare(W_plus_inv_jet, r'Invariant mass of $W^{+}$ (re-construct by jet)', W_plus_inv_jet_chi2, "./Pic/compare/inv_W_plus_jet_compare.png")

# %%
plot_hist_W(W_minus_inv_jet, r'Invariant mass of $W^{-}$ (re-construct by jet)', "./Pic/deltaR/inv_W_minus_jet.png")
plot_hist_W(W_minus_inv_jet_chi2, r'Invariant mass of $W^{-}$ (re-construct by jet, chi2)', "./Pic/chi2/inv_W_minus_jet_chi2.png")
plot_hist_W_compare(W_minus_inv_jet, r'Invariant mass of $W^{-}$ (re-construct by jet)', W_minus_inv_jet_chi2, "./Pic/compare/inv_W_minus_jet_compare.png")

# %%
t_inv_jet = []
t_bar_inv_jet = []

tmp = 0
tmp_p = 0

for i in range(len(N_match_top_in_event)):
    if N_match_top_in_event[i] == 2:
        for j in range(len(jet_parton_index[i])):
            
            if jet_parton_index[i][j] == 0:
                #jet_idx = int(parton_jet_index[i][j])
                pt_0 = jet_pt[i][j]
                eta_0 = jet_eta[i][j]
                phi_0 = jet_phi[i][j]
                mass_0 = jet_mass[i][j]
                px_0 = pt_0*np.cos( phi_0 )
                py_0 = pt_0*np.sin( phi_0 )
                pz_0 = pt_0*np.sinh( eta_0 )
                e_0 = np.sqrt( (px_0**2 + py_0**2 + pz_0**2 ) + mass_0**2 ) 
                #print("b cand:", j, pt_0, eta_0, phi_0, px_0, py_0, pz_0, e_0)

            if jet_parton_index[i][j] == 1:
                #jet_idx = int(parton_jet_index[i][j])
                pt_1 = jet_pt[i][j]
                eta_1 = jet_eta[i][j]
                phi_1 = jet_phi[i][j]
                mass_1 = jet_mass[i][j]
                px_1 = pt_1*np.cos( phi_1 )
                py_1 = pt_1*np.sin( phi_1 )
                pz_1 = pt_1*np.sinh( eta_1 )
                e_1 = np.sqrt( (px_1**2 + py_1**2 + pz_1**2 ) + mass_1**2 ) 
                #print("W daughter 1:", j, pt_1, eta_1, phi_1, px_1, py_1, pz_1, e_1)

            if jet_parton_index[i][j] == 2:
                #jet_idx = int(parton_jet_index[i][j])
                pt_2 = jet_pt[i][j]
                eta_2 = jet_eta[i][j]
                phi_2 = jet_phi[i][j]
                mass_2 = jet_mass[i][j]
                px_2 = pt_2*np.cos( phi_2 )
                py_2 = pt_2*np.sin( phi_2 )
                pz_2 = pt_2*np.sinh( eta_2 )
                e_2 = np.sqrt( (px_2**2 + py_2**2 + pz_2**2 ) + mass_2**2 )
                #print("W daughter 2:", j, pt_2, eta_2, phi_2, px_2, py_2, pz_2, e_2)

            if jet_parton_index[i][j] == 3:
                #jet_idx = int(parton_jet_index[i][j])
                pt_3 = jet_pt[i][j]
                eta_3 = jet_eta[i][j]
                phi_3 = jet_phi[i][j]
                mass_3 = jet_mass[i][j]
                px_3 = pt_3*np.cos( phi_3 )
                py_3 = pt_3*np.sin( phi_3 )
                pz_3 = pt_3*np.sinh( eta_3 )
                e_3 = np.sqrt( (px_3**2 + py_3**2 + pz_3**2 ) + mass_3**2 )
                #print("b bar cand:", j, pt_3, eta_3, phi_3, px_3, py_3, pz_3, e_3)

            if jet_parton_index[i][j] == 4:
                #jet_idx = int(parton_jet_index[i][j])
                pt_4 = jet_pt[i][j]
                eta_4 = jet_eta[i][j]
                phi_4 = jet_phi[i][j]
                mass_4 = jet_mass[i][j]
                px_4 = pt_4*np.cos( phi_4 )
                py_4 = pt_4*np.sin( phi_4 )
                pz_4 = pt_4*np.sinh( eta_4 )
                e_4 = np.sqrt( (px_4**2 + py_4**2 + pz_4**2 ) + mass_4**2 )
                #print("W- daughter 1:", j, pt_4, eta_4, phi_4, px_4, py_4, pz_4, e_4)

            if jet_parton_index[i][j] == 5:
                #jet_idx = int(parton_jet_index[i][j])
                pt_5 = jet_pt[i][j]
                eta_5 = jet_eta[i][j]
                phi_5 = jet_phi[i][j]
                mass_5 = jet_mass[i][j]
                px_5 = pt_5*np.cos( phi_5 )
                py_5 = pt_5*np.sin( phi_5 )
                pz_5 = pt_5*np.sinh( eta_5 )
                e_5 = np.sqrt( (px_5**2 + py_5**2 + pz_5**2 ) + mass_5**2 )
                #print("W- daughter 2:", j, pt_5, eta_5, phi_5, px_5, py_5, pz_5, e_5)

        tmp = np.sqrt( (e_0 + e_1 + e_2)**2 - (px_0 + px_1 + px_2)**2 - (py_0 + py_1 + py_2)**2 - (pz_0 + pz_1 + pz_2)**2 )
        tmp_p = np.sqrt( (e_3 + e_4 + e_5)**2 - (px_3 + px_4 + px_5)**2 - (py_3 + py_4 + py_5)**2 - (pz_3 + pz_4 + pz_5)**2 )
        t_inv_jet.append(tmp)
        t_bar_inv_jet.append(tmp_p)

# %%
t_inv_jet_chi2 = []
t_bar_inv_jet_chi2 = []

tmp = 0
tmp_p = 0

for i in range(len(N_match_top_in_event_chi2)):
    if N_match_top_in_event_chi2[i] == 2:
        for j in range(len(jet_parton_index_chi2[i])):
            
            if jet_parton_index_chi2[i][j] == 0:
                #jet_idx = int(parton_jet_index[i][j])
                pt_0 = jet_pt_chi2[i][j]
                eta_0 = jet_eta_chi2[i][j]
                phi_0 = jet_phi_chi2[i][j]
                mass_0 = jet_mass_chi2[i][j]
                px_0 = pt_0*np.cos( phi_0 )
                py_0 = pt_0*np.sin( phi_0 )
                pz_0 = pt_0*np.sinh( eta_0 )
                e_0 = np.sqrt( (px_0**2 + py_0**2 + pz_0**2 ) + mass_0**2 ) 
                #print("b cand:", j, pt_0, eta_0, phi_0, px_0, py_0, pz_0, e_0)

            if jet_parton_index_chi2[i][j] == 1:
                #jet_idx = int(parton_jet_index[i][j])
                pt_1 = jet_pt_chi2[i][j]
                eta_1 = jet_eta_chi2[i][j]
                phi_1 = jet_phi_chi2[i][j]
                mass_1 = jet_mass_chi2[i][j]
                px_1 = pt_1*np.cos( phi_1 )
                py_1 = pt_1*np.sin( phi_1 )
                pz_1 = pt_1*np.sinh( eta_1 )
                e_1 = np.sqrt( (px_1**2 + py_1**2 + pz_1**2 ) + mass_1**2 ) 
                #print("W daughter 1:", j, pt_1, eta_1, phi_1, px_1, py_1, pz_1, e_1)

            if jet_parton_index_chi2[i][j] == 2:
                #jet_idx = int(parton_jet_index[i][j])
                pt_2 = jet_pt_chi2[i][j]
                eta_2 = jet_eta_chi2[i][j]
                phi_2 = jet_phi_chi2[i][j]
                mass_2 = jet_mass_chi2[i][j]
                px_2 = pt_2*np.cos( phi_2 )
                py_2 = pt_2*np.sin( phi_2 )
                pz_2 = pt_2*np.sinh( eta_2 )
                e_2 = np.sqrt( (px_2**2 + py_2**2 + pz_2**2 ) + mass_2**2 )
                #print("W daughter 2:", j, pt_2, eta_2, phi_2, px_2, py_2, pz_2, e_2)

            if jet_parton_index_chi2[i][j] == 3:
                #jet_idx = int(parton_jet_index[i][j])
                pt_3 = jet_pt_chi2[i][j]
                eta_3 = jet_eta_chi2[i][j]
                phi_3 = jet_phi_chi2[i][j]
                mass_3 = jet_mass_chi2[i][j]
                px_3 = pt_3*np.cos( phi_3 )
                py_3 = pt_3*np.sin( phi_3 )
                pz_3 = pt_3*np.sinh( eta_3 )
                e_3 = np.sqrt( (px_3**2 + py_3**2 + pz_3**2 ) + mass_3**2 )
                #print("b bar cand:", j, pt_3, eta_3, phi_3, px_3, py_3, pz_3, e_3)

            if jet_parton_index_chi2[i][j] == 4:
                #jet_idx = int(parton_jet_index[i][j])
                pt_4 = jet_pt_chi2[i][j]
                eta_4 = jet_eta_chi2[i][j]
                phi_4 = jet_phi_chi2[i][j]
                mass_4 = jet_mass_chi2[i][j]
                px_4 = pt_4*np.cos( phi_4 )
                py_4 = pt_4*np.sin( phi_4 )
                pz_4 = pt_4*np.sinh( eta_4 )
                e_4 = np.sqrt( (px_4**2 + py_4**2 + pz_4**2 ) + mass_4**2 )
                #print("W- daughter 1:", j, pt_4, eta_4, phi_4, px_4, py_4, pz_4, e_4)

            if jet_parton_index_chi2[i][j] == 5:
                #jet_idx = int(parton_jet_index[i][j])
                pt_5 = jet_pt_chi2[i][j]
                eta_5 = jet_eta_chi2[i][j]
                phi_5 = jet_phi_chi2[i][j]
                mass_5 = jet_mass_chi2[i][j]
                px_5 = pt_5*np.cos( phi_5 )
                py_5 = pt_5*np.sin( phi_5 )
                pz_5 = pt_5*np.sinh( eta_5 )
                e_5 = np.sqrt( (px_5**2 + py_5**2 + pz_5**2 ) + mass_5**2 )
                #print("W- daughter 2:", j, pt_5, eta_5, phi_5, px_5, py_5, pz_5, e_5)

        tmp = np.sqrt( (e_0 + e_1 + e_2)**2 - (px_0 + px_1 + px_2)**2 - (py_0 + py_1 + py_2)**2 - (pz_0 + pz_1 + pz_2)**2 )
        tmp_p = np.sqrt( (e_3 + e_4 + e_5)**2 - (px_3 + px_4 + px_5)**2 - (py_3 + py_4 + py_5)**2 - (pz_3 + pz_4 + pz_5)**2 )
        t_inv_jet_chi2.append(tmp)
        t_bar_inv_jet_chi2.append(tmp_p)

# %%
plot_hist_top(t_inv_jet, r'Invariant mass of $t$ (re-construct by jet)', "./Pic/deltaR/inv_top_jet.png")
plot_hist_top(t_inv_jet_chi2, r'Invariant mass of $t$ (re-construct by jet, chi2)', "./Pic/chi2/inv_top_jet_chi2.png")
plot_hist_top_compare(t_inv_jet, r'Invariant mass of $t$ (re-construct by jet)', t_inv_jet_chi2, "./Pic/compare/inv_top_jet_compare.png")

# %%
plot_hist_top(t_bar_inv_jet, r'Invariant mass of $\bar{t}$ (re-construct by jet)', "./Pic/deltaR/inv_top_bar_jet.png")
plot_hist_top(t_bar_inv_jet_chi2, r'Invariant mass of $\bar{t}$ (re-construct by jet, chi2)', "./Pic/chi2/inv_top_bar_jet_chi2.png")
plot_hist_top_compare(t_bar_inv_jet, r'Invariant mass of $\bar{t}$ (re-construct by jet)', t_bar_inv_jet_chi2, "./Pic/compare/inv_top_bar_jet_compare.png")
